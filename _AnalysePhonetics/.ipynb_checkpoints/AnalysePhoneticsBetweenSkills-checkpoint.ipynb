# %% [markdown]
# # AnalysePhoneticsBetweenSkills

# %% [raw]
# In this notebook I perform some analysis between the phonetics of the different skills, using the CMU phonetic dictionary, and the levehnstein distance

# %%
#laod CMU dict
CMUpath = 'cmudict_SPHINX_40.txt'
cmu_dict = {}
with open(CMUpath, "r", encoding='utf8') as f:
    for line in f:
        #A line looks like this
        #ABORT	AH B AO R T
        if line and len(line.strip())>0:
            spl = line.split('\t')
            word = spl[0].strip()
            phonemes = spl[1].strip()
            cmu_dict[word] = phonemes.split(' ')

# %%
'''
Call getPhoneticTranslation to get the phonetic trasnlation of a sentence. 
It cleans the word and obtains a CMU translation of the sentence.
Replaces the non existent words in the dictionary by a word of the same length formed by '_'
'''

import string
invalidChars = set(string.punctuation)
numbers = {'0':'ZERO','1':'ONE','2':'TWO','3':'THREE','4':'FOUR','5':'FIVE',
           '6':'SIX','7':'SEVEN','8':'EIGHT','9':'NINE'}
def getPhoneticTranslation(sentence):
    #Transcriptions to be compared were converted to uppercase and all non-ASCII characters and punctuation were
    #removed. Digits were replaced with their corresponding texts (e.g., “2” became “two”)
    def PreProcessWord(word):
        for c in invalidChars:
            if c in word:
                word = word.replace(c,'')
        for n in numbers.keys():
            if n in word:
                word = word.replace(n, ' '+numbers[n]+' ')

        word = word.upper()
        word = word.replace('  ', ' ')
        return word.strip()

    a=PreProcessWord(sentence)
    cmutranslated = []
    for w in a.split(' '):
        if w in cmu_dict:
            b = cmu_dict[w]
        else:
            b = ['_']*len(w)
        cmutranslated+= b+[' ']
    return cmutranslated[:len(cmutranslated)-1]
    



#example of the process
word = '123feeli_ng down!'
print('*', word)
print(getPhoneticTranslation(word))
word = 'Apple watch --!'
print('*', word)
print(getPhoneticTranslation(word))
word = 'Unexxxxisting word but the rest is fine'
print('*', word)
print(getPhoneticTranslation(word))
# Out:
# * 123feeli_ng down!
# ['W', 'AH', 'N', ' ', 'T', 'UW', ' ', 'TH', 'R', 'IY', ' ', 'F', 'IY', 'L', 'IH', 'NG', ' ', 'D', 'AW', 'N']
# * Apple watch --!
# ['AE', 'P', 'AH', 'L', ' ', 'W', 'AA', 'CH']
# * Unexxxxisting word but the rest is fine
# ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', ' ', 'W', 'ER', 'D', ' ', 'B', 'AH', 'T', ' ', 'DH', 'AH', ' ', 'R', 'EH', 'S', 'T', ' ', 'IH', 'Z', ' ', 'F', 'AY', 'N']

# %% [markdown]
# ### Load new Alexa Dataset

# %%
#Load dataset
import os
import json

def reloadData():
    def getFiles(dirName):
        listOfFile = os.listdir(dirName)
        completeFileList = list()
        for file in listOfFile:
            completePath = os.path.join(dirName, file)
            if os.path.isdir(completePath):
                completeFileList = completeFileList + getFiles(completePath)
            elif '.json' in completePath:
                completeFileList.append(completePath.replace('\\', '/'))

        return completeFileList

    allf = getFiles( "../NewFullDataset/")
    print(allf)

    #create dictionary of markets and skills
    skillsmarketd = {}
    for f in allf:
        marketname = f.split('/')[2].split('.json')[0]
        with open(f, 'r') as json_file:
            skillsmarketd[marketname] = json.load(json_file)

    print()
    print('Total unique skills per market as per last week')
    for key,value in skillsmarketd.items():
        print(key, ": ", len(value))
    print()
    print()
    return skillsmarketd

# %%
allskills = reloadData()
# Out:
# ['../NewFullDataset/AU.json', '../NewFullDataset/CA.json', '../NewFullDataset/DE.json', '../NewFullDataset/ES.json', '../NewFullDataset/FR.json', '../NewFullDataset/IN.json', '../NewFullDataset/IT.json', '../NewFullDataset/JP.json', '../NewFullDataset/MX.json', '../NewFullDataset/UK.json', '../NewFullDataset/US.json']
#
# Total unique skills per market as per last week
# AU :  24062
# CA :  26009
# DE :  9082
# ES :  4756
# FR :  2282
# IN :  29249
# IT :  4202
# JP :  3519
# MX :  1972
# UK :  30975
# US :  60298

# %% [markdown]
# ### Levenshtein Distance

# %%
import editdistance
#luckily I found this iplementation of levehenstein distance that goes almost 100 times faster than the defined above...
def levdistance(w1,w2):
    #if there is a difference of more than 3 words in the skil names, 
    #we are not interested in the real distance as they are not interesting
    if(w1 == w2):
        return 0
    if(len(w1) > len(w2)+2):
        return 1
    if(len(w2) > len(w1)+2):
        return 1
    return editdistance.eval(w1, w2)/ max(len(w1), len(w2))

# %%
levdistance(['ck', 'a', 't'], ['k', 'a', 't'])
# Out:
# 0.3333333333333333

# %% [markdown]
# ### Perform experiment for TABLE III.SKILL NAMES WITHLEVENSHTEIN DISTANCE≤0.2, considering english markets and ignoring words that do not have a CMU translation

# %% [markdown]
# #### NOTE: Do not run this, it takes a while!

# %%
import datetime

#explore the different markets per separate, otherwis eI get memory errors
data = reloadData()
englishmarkets = ['UK','AU', 'CA', 'IN', 'US']
for market in englishmarkets:
    uniqskcount = {} #dictionary that contains the quantity of skills for each element
    skilltocmu = {}  #set of unique skill names considered and their translation to phonetics
    
    '''
    Create skilltocmu dict
    '''
    print('Exploring market', market)
    skills = data[market]
    for skillid, skillobj in skills.items():
        name1 = skillobj['name'].lower()
        cmuname = getPhoneticTranslation(name1)
        #we ignore skills we couldnt completely trasnalte (include '_') [also to speed up the process]
        if '_' not in cmuname:
            skilltocmu[name1] = cmuname
            if(name1 in uniqskcount):
                uniqskcount[name1] += 1
            else:
                uniqskcount[name1] = 1
    print('finished creating crate skilltocmu dict for market', market)    

    '''
    Calculate levehenstein distances:
    This process is super slow. We do many tricks to speed up the process:
        1- since we are only interested in super similar skill names, we ignore words with different lengths (see lev function above)
        2- we only iterate trhough unique skill names transformed to lower, hence the results may be different as 
        in other figures since 'catFacts' and 'CatFacts' are considered the same skill
        3- We only identify which skill names have levehenstein distances < 0.1 or 0.2 (to reduce the final json files).
        Then, we count how many of skills with this name.lower() exist in the market to get hte data for table III
    '''
    alldistances = set([])
    uniqsk = list(skilltocmu.keys())
    totalanalysed = 0
    for i in range(len(uniqsk)):
        name1 = uniqsk[i].lower()
        if(name1 not in skilltocmu):
            continue
        cmuname1 = skilltocmu[name1]
        for j in range(i, len(uniqsk)):
            name2 = uniqsk[j].lower()
            if(name2 not in skilltocmu):
                continue
            cmuname2 = skilltocmu[name2]
            d=  levdistance(cmuname1, cmuname2)
            if(d<0.31):
                #only save these skills with smaller lev distances (otherwise memory error)
                alldistances.add( (d,name1,name2) )
            #count all distances processed
            totalanalysed +=1
            
        if(i%1000 == 0):
            now = datetime.datetime.now()
            print('\t[',now.hour,':',now.minute,'.',now.second,'] Distances computed ', i)
     
    
    
    #save analysis in PhonDict json
    path = 'PhonDict/'+market+'.json'
    with open(path, 'w') as json_file:
        print('Saving json in ',path)
        json.dump( {'phonetic_distances_minororequal03':list(alldistances), 'all_distances_processed':totalanalysed, 'skillnames_count_d':uniqskcount} , json_file)    
    
    #min01 = [d for d in alldistances if d <= 0.1 and d!=0]
    #min02 = [d for d in alldistances if d <= 0.2 and d!=0]
    ##we should count how many times this skills appear in the market!
    #print('There are ', len(min01), 'skills within a ld of 0.1')
    #print('There are ', len(min02), 'skills within a ld of 0.2')
    #print('Total unique skill names ', len(uniqsk))
    #
    now = datetime.datetime.now()
    print('[',now.hour,':',now.minute,'.',now.second,'] Finished estiamting skill names levehenstein distances for market', market)
# Out:
# ['../NewFullDataset/AU.json', '../NewFullDataset/CA.json', '../NewFullDataset/DE.json', '../NewFullDataset/ES.json', '../NewFullDataset/FR.json', '../NewFullDataset/IN.json', '../NewFullDataset/IT.json', '../NewFullDataset/JP.json', '../NewFullDataset/MX.json', '../NewFullDataset/UK.json', '../NewFullDataset/US.json']
#
# Total unique skills per market as per last week
# AU :  24062
# CA :  26009
# DE :  9082
# ES :  4756
# FR :  2282
# IN :  29249
# IT :  4202
# JP :  3519
# MX :  1972
# UK :  30975
# US :  60298
#
#
# Exploring market UK
# finished creating crate skilltocmu dict for market UK
# 	[ 9 : 21 . 37 ] Distances computed  0
# 	[ 9 : 22 . 5 ] Distances computed  1000
# 	[ 9 : 22 . 30 ] Distances computed  2000
# 	[ 9 : 22 . 55 ] Distances computed  3000
# 	[ 9 : 23 . 19 ] Distances computed  4000
# 	[ 9 : 23 . 40 ] Distances computed  5000
# 	[ 9 : 24 . 0 ] Distances computed  6000
# 	[ 9 : 24 . 20 ] Distances computed  7000
# 	[ 9 : 24 . 39 ] Distances computed  8000
# 	[ 9 : 24 . 54 ] Distances computed  9000
# 	[ 9 : 25 . 9 ] Distances computed  10000
# 	[ 9 : 25 . 22 ] Distances computed  11000
# 	[ 9 : 25 . 34 ] Distances computed  12000
# 	[ 9 : 25 . 44 ] Distances computed  13000
# 	[ 9 : 25 . 52 ] Distances computed  14000
# 	[ 9 : 25 . 59 ] Distances computed  15000
# 	[ 9 : 26 . 4 ] Distances computed  16000
# 	[ 9 : 26 . 9 ] Distances computed  17000
# 	[ 9 : 26 . 11 ] Distances computed  18000
# Saving json in  PhonDict/UK.json
# [ 9 : 26 . 12 ] Finished estiamting skill names levehenstein distances for market UK
# Exploring market AU
# finished creating crate skilltocmu dict for market AU
# 	[ 9 : 26 . 12 ] Distances computed  0
# 	[ 9 : 26 . 36 ] Distances computed  1000
# 	[ 9 : 26 . 59 ] Distances computed  2000
# 	[ 9 : 27 . 20 ] Distances computed  3000
# 	[ 9 : 27 . 39 ] Distances computed  4000
# 	[ 9 : 27 . 56 ] Distances computed  5000
# 	[ 9 : 28 . 13 ] Distances computed  6000
# 	[ 9 : 28 . 27 ] Distances computed  7000
# 	[ 9 : 28 . 40 ] Distances computed  8000
# 	[ 9 : 28 . 51 ] Distances computed  9000
# 	[ 9 : 29 . 0 ] Distances computed  10000
# 	[ 9 : 29 . 8 ] Distances computed  11000
# 	[ 9 : 29 . 14 ] Distances computed  12000
# 	[ 9 : 29 . 18 ] Distances computed  13000
# 	[ 9 : 29 . 21 ] Distances computed  14000
# 	[ 9 : 29 . 22 ] Distances computed  15000
# Saving json in  PhonDict/AU.json
# [ 9 : 29 . 23 ] Finished estiamting skill names levehenstein distances for market AU
# Exploring market CA
# finished creating crate skilltocmu dict for market CA
# 	[ 9 : 29 . 24 ] Distances computed  0
# 	[ 9 : 29 . 48 ] Distances computed  1000
# 	[ 9 : 30 . 10 ] Distances computed  2000
# 	[ 9 : 30 . 33 ] Distances computed  3000
# 	[ 9 : 30 . 54 ] Distances computed  4000
# 	[ 9 : 31 . 12 ] Distances computed  5000
# 	[ 9 : 31 . 30 ] Distances computed  6000
# 	[ 9 : 31 . 44 ] Distances computed  7000
# 	[ 9 : 31 . 57 ] Distances computed  8000
# 	[ 9 : 32 . 7 ] Distances computed  9000
# 	[ 9 : 32 . 17 ] Distances computed  10000
# 	[ 9 : 32 . 25 ] Distances computed  11000
# 	[ 9 : 32 . 32 ] Distances computed  12000
# 	[ 9 : 32 . 38 ] Distances computed  13000
# 	[ 9 : 32 . 42 ] Distances computed  14000
# 	[ 9 : 32 . 45 ] Distances computed  15000
# 	[ 9 : 32 . 47 ] Distances computed  16000
# Saving json in  PhonDict/CA.json
# [ 9 : 32 . 48 ] Finished estiamting skill names levehenstein distances for market CA
# Exploring market IN
# finished creating crate skilltocmu dict for market IN
# 	[ 9 : 32 . 48 ] Distances computed  0
# 	[ 9 : 33 . 14 ] Distances computed  1000
# 	[ 9 : 33 . 39 ] Distances computed  2000
# 	[ 9 : 34 . 2 ] Distances computed  3000
# 	[ 9 : 34 . 22 ] Distances computed  4000
# 	[ 9 : 34 . 40 ] Distances computed  5000
# 	[ 9 : 34 . 58 ] Distances computed  6000
# 	[ 9 : 35 . 14 ] Distances computed  7000
# 	[ 9 : 35 . 29 ] Distances computed  8000
# 	[ 9 : 35 . 41 ] Distances computed  9000
# 	[ 9 : 35 . 52 ] Distances computed  10000
# 	[ 9 : 36 . 2 ] Distances computed  11000
# 	[ 9 : 36 . 9 ] Distances computed  12000
# 	[ 9 : 36 . 15 ] Distances computed  13000
# 	[ 9 : 36 . 20 ] Distances computed  14000
# 	[ 9 : 36 . 24 ] Distances computed  15000
# 	[ 9 : 36 . 25 ] Distances computed  16000
# Saving json in  PhonDict/IN.json
# [ 9 : 36 . 26 ] Finished estiamting skill names levehenstein distances for market IN
# Exploring market US
# finished creating crate skilltocmu dict for market US
# 	[ 9 : 36 . 27 ] Distances computed  0
# 	[ 9 : 37 . 18 ] Distances computed  1000
# 	[ 9 : 38 . 8 ] Distances computed  2000
# 	[ 9 : 39 . 1 ] Distances computed  3000
# 	[ 9 : 39 . 55 ] Distances computed  4000
# 	[ 9 : 40 . 46 ] Distances computed  5000
# 	[ 9 : 41 . 33 ] Distances computed  6000
# 	[ 9 : 42 . 20 ] Distances computed  7000
# 	[ 9 : 43 . 8 ] Distances computed  8000
# 	[ 9 : 43 . 54 ] Distances computed  9000
# 	[ 9 : 44 . 38 ] Distances computed  10000
# 	[ 9 : 45 . 20 ] Distances computed  11000
# 	[ 9 : 45 . 59 ] Distances computed  12000
# 	[ 9 : 46 . 39 ] Distances computed  13000
# 	[ 9 : 47 . 7 ] Distances computed  14000
# 	[ 9 : 47 . 36 ] Distances computed  15000
# 	[ 9 : 48 . 8 ] Distances computed  16000
# 	[ 9 : 48 . 41 ] Distances computed  17000
# 	[ 9 : 49 . 12 ] Distances computed  18000
# 	[ 9 : 49 . 42 ] Distances computed  19000
# 	[ 9 : 50 . 11 ] Distances computed  20000
# 	[ 9 : 50 . 37 ] Distances computed  21000
# 	[ 9 : 51 . 2 ] Distances computed  22000
# 	[ 9 : 51 . 26 ] Distances computed  23000
# 	[ 9 : 51 . 47 ] Distances computed  24000
# 	[ 9 : 52 . 6 ] Distances computed  25000
# 	[ 9 : 52 . 24 ] Distances computed  26000
# 	[ 9 : 52 . 39 ] Distances computed  27000
# 	[ 9 : 52 . 55 ] Distances computed  28000
# 	[ 9 : 53 . 9 ] Distances computed  29000
# 	[ 9 : 53 . 22 ] Distances computed  30000
# 	[ 9 : 53 . 34 ] Distances computed  31000
# 	[ 9 : 53 . 44 ] Distances computed  32000
# 	[ 9 : 53 . 51 ] Distances computed  33000
# 	[ 9 : 53 . 58 ] Distances computed  34000
# 	[ 9 : 54 . 2 ] Distances computed  35000
# 	[ 9 : 54 . 5 ] Distances computed  36000
# 	[ 9 : 54 . 7 ] Distances computed  37000
# Saving json in  PhonDict/US.json
# [ 9 : 54 . 9 ] Finished estiamting skill names levehenstein distances for market US

# %% [markdown]
# ### Load the dictionaries of words and get the data for table III

# %%
def getFiles(dirName):
    listOfFile = os.listdir(dirName)
    completeFileList = list()
    for file in listOfFile:
        completePath = os.path.join(dirName, file)
        if os.path.isdir(completePath):
            completeFileList = completeFileList + getFiles(completePath)
        elif '.json' in completePath:
            completeFileList.append(completePath.replace('\\', '/'))

    return completeFileList

#load the jsons
alljsons = getFiles('PhonDict/')
phondict = {}
for f in alljsons:
    market = f.split('/')[1].split('.json')[0]
    print('Loaded json for ', market, ' :', f)
    with open(f, 'r') as json_file:
        phondict[market] = json.load(json_file)
        
#get the data
for market in phondict:
    print('Studying market', market)
    phondist = phondict[market]['phonetic_distances_minororequal03']
    totalcomparisons = phondict[market]['all_distances_processed']
    skillnamecount_d = phondict[market]['skillnames_count_d']
    totalskills_hits = sum(skillnamecount_d.values())
    print('Total hits for unique skill names.lower() ', totalskills_hits)
    
    '''
    find, for every unique name skill.lower(), the minimum distance to any other skill.lower()
    '''
    min_d_skillname = {}
    for skillname in skillnamecount_d.keys():
        #print('exploring skill ', skillname)
        alldforskill = [(d, sk1, sk2) for (d, sk1, sk2) in phondist if (sk1 == skillname or sk2 == skillname) and d!=0]        
        if(len(alldforskill)>0):
            min_d_skillname[skillname] = min([d for (d, sk1, sk2) in alldforskill ])
        else:
            min_d_skillname[skillname] = 1
    '''
    now, iterate over all unique skills.lower(), and bin them < 0.1 and < 0.2
    '''
    min_d_skillname_l = [ (k,v) for (k,v) in min_d_skillname.items()]
    #get these skills with a minimum lev distance to any other skill name of 0.1
    min01 = [(skname, skmin) for (skname, skmin) in min_d_skillname_l if skmin <= 0.1]
    #get how many skills are aggregated with that specific name
    total01 = sum([skillnamecount_d[skname] for (skname, skmin) in min01])
    print('There are ', len(min01), 'skills within a ld of 0.1 to any other skillname that does not contain '_''', addding a total of hits ', total01, '(',total01/totalskills_hits,'%)')
    
    #get these skills with a minimum lev distance to any other skill name of 0.1
    min02 = [(skname, skmin) for (skname, skmin) in min_d_skillname_l if skmin <= 0.2]
    #get how many skills are aggregated with that specific name
    total02 = sum([skillnamecount_d[skname] for (skname, skmin) in min02])
    print('There are ', len(min02), 'skills within a ld of 0.1 to any other skillname that does not contain '_', addding a total of hits ', total02, '(',total02/totalskills_hits,'%)')
# Out:
# Loaded json for  AU  : PhonDict/AU.json
# Loaded json for  CA  : PhonDict/CA.json
# Loaded json for  IN  : PhonDict/IN.json
# Loaded json for  UK  : PhonDict/UK.json
# Loaded json for  US  : PhonDict/US.json
# Studying market AU
# Total hits for unique skill names.lower()  17974

# %%
min01
# Out:
# [('dungeon roll', 0.09090909090909091),
#  ('categories game', 0.07692307692307693),
#  ('voice of the day', 0.08333333333333333),
#  ('battle tracks', 0.09090909090909091),
#  ('inspirational quote', 0.058823529411764705),
#  ('nature sounds', 0.1),
#  ('rock paper scissor', 0.07142857142857142),
#  ('what the facts', 0.08333333333333333),
#  ('train sounds', 0.1),
#  ('nature sound', 0.1),
#  ('water drop sound', 0.06666666666666667),
#  ('crazy fact', 0.09090909090909091),
#  ('rock paper scissors', 0.07142857142857142),
#  ('stone paper scissor', 0.06666666666666667),
#  ('ocean sound', 0.1),
#  ('rowdy radio', 0.1),
#  ('capitals quiz', 0.07692307692307693),
#  ('thunder sound', 0.09090909090909091),
#  ('train sound', 0.1),
#  ('wind sound', 0.1),
#  ('forest sound', 0.08333333333333333),
#  ('sports quiz', 0.09090909090909091),
#  ('nepali date', 0.1),
#  ('inspirational quotes', 0.058823529411764705),
#  ('relaxing sleep sounds: ocean sounds', 0.1),
#  ('rudy radio', 0.1),
#  ('heavy rain sound', 0.07142857142857142),
#  ('relaxing sleep sounds: rain sounds', 0.06896551724137931),
#  ('brilliance smart', 0.07142857142857142),
#  ('crypto currencies', 0.07142857142857142),
#  ('crypto currency', 0.07142857142857142),
#  ('crypto price check', 0.0625),
#  ('crypto price checker', 0.0625),
#  ('dummy facts', 0.1),
#  ('daily quotes', 0.1),
#  ('india facts', 0.08333333333333333),
#  ('upon this day - in history', 0.09523809523809523),
#  ('roll the dice', 0.1),
#  ('plant facts', 0.08333333333333333),
#  ('dog facts', 0.1),
#  ('water facts', 0.1),
#  ('drone facts', 0.1),
#  ('mango facts', 0.09090909090909091),
#  ('australia facts', 0.07142857142857142),
#  ('sex facts', 0.1),
#  ('magic words', 0.1),
#  ('facts guru', 0.1),
#  ('banana fact', 0.08333333333333333),
#  ('artificial intelligence facts', 0.07142857142857142),
#  ('tiger facts', 0.1),
#  ('bear facts', 0.1),
#  ('jellyfish facts', 0.07142857142857142),
#  ('awesome facts', 0.09090909090909091),
#  ('eagle facts', 0.09090909090909091),
#  ('elephants facts', 0.07142857142857142),
#  ('parrot facts', 0.08333333333333333),
#  ('funny facts', 0.1),
#  ('born on november fifteen', 0.09090909090909091),
#  ('born on november fourteen', 0.09090909090909091),
#  ('crazy facts', 0.09090909090909091),
#  ('born on november thirteen', 0.09523809523809523),
#  ('fun facts', 0.1),
#  ('strange facts', 0.08333333333333333),
#  ('amazing facts', 0.08333333333333333),
#  ('born on november eighteen', 0.09523809523809523),
#  ('possum facts', 0.09090909090909091),
#  ('born on november eight', 0.1),
#  ('honey bee facts', 0.07692307692307693),
#  ('born on november ten', 0.1),
#  ('john wooden quotes', 0.06666666666666667),
#  ('nutrition facts', 0.07142857142857142),
#  ('money quotes', 0.1),
#  ('number facts', 0.08333333333333333),
#  ('christmas facts', 0.07692307692307693),
#  ('tennessee facts', 0.08333333333333333),
#  ('arizona facts', 0.07692307692307693),
#  ('droll facts', 0.1),
#  ('silly facts', 0.1),
#  ('number fact', 0.09090909090909091),
#  ('dolphins facts', 0.07692307692307693),
#  ('sport facts', 0.08333333333333333),
#  ('nutritious facts', 0.07142857142857142),
#  ('strange  facts', 0.08333333333333333),
#  ('american facts', 0.07142857142857142),
#  ('camels facts', 0.08333333333333333),
#  ('amazing  facts', 0.08333333333333333),
#  ('queen facts', 0.1),
#  ('useless facts', 0.08333333333333333),
#  ('environment fact', 0.058823529411764705),
#  ('south african facts', 0.058823529411764705),
#  ('buddha quotes', 0.1),
#  ('soccer facts', 0.1),
#  ('space facts', 0.1),
#  ('hippo facts', 0.1),
#  ('desert facts', 0.09090909090909091),
#  ('fruit facts', 0.09090909090909091),
#  ('star trek facts', 0.06666666666666667),
#  ('shark facts', 0.1),
#  ('random facts', 0.08333333333333333),
#  ('germany facts', 0.08333333333333333),
#  ('brain facts', 0.1),
#  ('jelly fish facts', 0.07142857142857142),
#  ('sports facts', 0.08333333333333333),
#  ('incredible indian facts', 0.043478260869565216),
#  ('galaxy facts', 0.07692307692307693),
#  ('planet facts', 0.08333333333333333),
#  ('fruits facts', 0.09090909090909091),
#  ('what a fact', 0.09090909090909091),
#  ('star facts', 0.1),
#  ('dolphin facts', 0.07692307692307693),
#  ('cosmetic facts', 0.06666666666666667),
#  ('funny quotes', 0.1),
#  ('russia facts', 0.09090909090909091),
#  ('heart facts', 0.1),
#  ('indonesia facts', 0.06666666666666667),
#  ('asia facts', 0.1),
#  ('random fun facts', 0.058823529411764705),
#  ('cancer facts', 0.09090909090909091),
#  ('banana facts', 0.08333333333333333),
#  ('cobalt facts', 0.08333333333333333),
#  ('zinc facts', 0.1),
#  ('venus facts', 0.09090909090909091),
#  ('camel facts', 0.08333333333333333),
#  ('fox facts', 0.1),
#  ('elephant facts', 0.07142857142857142),
#  ('horse facts', 0.1),
#  ('dreams facts', 0.09090909090909091),
#  ('comic quiz', 0.09090909090909091),
#  ('movies quiz', 0.1),
#  ('spider facts', 0.09090909090909091),
#  ('verse of the day', 0.08333333333333333),
#  ('random quotes', 0.08333333333333333),
#  ('animal sound quiz', 0.058823529411764705),
#  ('mayan facts', 0.1),
#  ('donald trump facts', 0.05555555555555555),
#  ('fat facts', 0.1),
#  ('amazing fact', 0.08333333333333333),
#  ('technology facts', 0.06666666666666667),
#  ('ai (artificial intelligence) facts', 0.07142857142857142),
#  ('multiplication tables', 0.05),
#  ('times tables', 0.09090909090909091),
#  ('indian facts', 0.08333333333333333),
#  ('motivational quote', 0.058823529411764705),
#  ("new year's resolutions", 0.05555555555555555),
#  ('motivational quotes', 0.058823529411764705),
#  ('multiplication spot quiz for third graders', 0.07692307692307693),
#  ('history facts', 0.08333333333333333),
#  ('daily quote', 0.1),
#  ('animal sounds quiz', 0.058823529411764705),
#  ('number game', 0.1),
#  ('random numbers', 0.07692307692307693),
#  ('multiplication spot quiz for first graders', 0.07692307692307693),
#  ('subtraction spot quiz for fifth graders', 0.05555555555555555),
#  ('subtraction spot quiz for fourth graders', 0.05555555555555555),
#  ('subtraction spot quiz for third graders', 0.08333333333333333),
#  ('counting things', 0.09090909090909091),
#  ('subtraction spot quiz for first graders', 0.08333333333333333),
#  ('addition spot quiz for fifth graders', 0.0625),
#  ('addition spot quiz for fourth graders', 0.0625),
#  ('science facts', 0.09090909090909091),
#  ('addition spot quiz for third graders', 0.09375),
#  ('addition spot quiz for first graders', 0.09375),
#  ('state capitals quiz', 0.05555555555555555),
#  ('some facts', 0.1),
#  ('thirteenth amendment to the u.s. constitution', 0.05405405405405406),
#  ('eleventh amendment to the u.s. constitution', 0.05263157894736842),
#  ('seventh amendment to the u.s. constitution', 0.05263157894736842),
#  ('eighteenth amendment to the u.s. constitution', 0.05405405405405406),
#  ('kid advice', 0.1),
#  ('john wooden quote', 0.06666666666666667),
#  ('guitar chords', 0.09090909090909091),
#  ('sachin facts', 0.09090909090909091),
#  ('oakland guide', 0.1),
#  ('delhi facts', 0.1),
#  ('golf facts', 0.1),
#  ('asian facts', 0.1),
#  ('wild animals facts', 0.05555555555555555),
#  ('dundee facts', 0.09090909090909091),
#  ('buddha quote', 0.1),
#  ('indian festivals', 0.0625),
#  ('korea facts', 0.08333333333333333),
#  ('golf fact', 0.1),
#  ('peanut butter fact', 0.0625),
#  ('technology fact', 0.06666666666666667),
#  ('archie facts', 0.09090909090909091),
#  ('baby help', 0.1),
#  ('famous quotes', 0.09090909090909091),
#  ('salmon facts', 0.09090909090909091),
#  ('desi facts', 0.1),
#  ('russian facts', 0.09090909090909091),
#  ('fortune cookie', 0.08333333333333333),
#  ('sneaker facts', 0.09090909090909091),
#  ('element facts', 0.07692307692307693),
#  ('state capital quiz', 0.05555555555555555),
#  ('inventors quiz', 0.07692307692307693),
#  ('hanukkah facts', 0.08333333333333333),
#  ('spider fact', 0.09090909090909091),
#  ('german facts', 0.08333333333333333),
#  ('flower facts', 0.1),
#  ('indian states capital', 0.1),
#  ('beagle fact', 0.09090909090909091),
#  ('water fact', 0.1),
#  ('roman facts', 0.09090909090909091),
#  ('interesting space facts', 0.1),
#  ('cobol facts', 0.08333333333333333),
#  ('indonesian facts', 0.06666666666666667),
#  ('elements quiz', 0.07692307692307693),
#  ('korean facts', 0.08333333333333333),
#  ('capital quiz', 0.07692307692307693),
#  ('bedtime story', 0.07692307692307693),
#  ('home workouts', 0.1),
#  ('barre facts', 0.1),
#  ('sound asleep', 0.1),
#  ('roma facts', 0.09090909090909091),
#  ('baby helper', 0.1),
#  ('home workout exercise videos fitness day 7 video', 0.06521739130434782),
#  ('home workout exercise videos fitness day 2 video', 0.06818181818181818),
#  ('home workout exercise videos fitness day 4 video', 0.045454545454545456),
#  ('home workout exercise videos fitness day 1 video', 0.06521739130434782),
#  ('home workout exercise videos fitness day 5 video', 0.045454545454545456),
#  ('sleep sounds: snoring sounds', 0.043478260869565216),
#  ('fart sound', 0.1),
#  ('happy quote', 0.1),
#  ('eagles facts', 0.09090909090909091),
#  ('cricket facts', 0.08333333333333333),
#  ('home workout', 0.1),
#  ('tennis facts', 0.08333333333333333),
#  ('soccer facts!', 0.1),
#  ('fun sports facts', 0.0625),
#  ('squat workout', 0.08333333333333333),
#  ('football teams', 0.09090909090909091),
#  ('squats workout', 0.08333333333333333),
#  ('sleeping sounds: relax, study or meditate', 0.08333333333333333),
#  ('cricket scorer', 0.08333333333333333),
#  ('cricket score', 0.08333333333333333),
#  ('indian food', 0.09090909090909091),
#  ('wine assistant', 0.08333333333333333),
#  ('wine trivia', 0.1),
#  ('rock, paper, scissors', 0.07142857142857142),
#  ('funny cat facts', 0.07142857142857142),
#  ('light rain sound', 0.07692307692307693),
#  ('musical trivia', 0.0625),
#  ('stone paper scissors', 0.06666666666666667),
#  ('roll a dice', 0.1),
#  ('random number', 0.07692307692307693),
#  ('fact facts', 0.1),
#  ('numbers facts', 0.08333333333333333),
#  ('numbers trivia', 0.07692307692307693),
#  ('bollywood facts', 0.07692307692307693),
#  ('comics quiz', 0.09090909090909091),
#  ('fax facts', 0.1),
#  ('australia fact', 0.07142857142857142),
#  ('super hero', 0.1),
#  ('movie quiz', 0.1),
#  ('fact guru', 0.1),
#  ('battle traps', 0.09090909090909091),
#  ('daily facts', 0.1),
#  ('wonderful penguins facts', 0.043478260869565216),
#  ('interesting snake facts', 0.1),
#  ('reindeer games', 0.09090909090909091),
#  ('guess the number', 0.08333333333333333),
#  ('new year fact', 0.08333333333333333),
#  ('guess a number', 0.08333333333333333),
#  ('on this day in history', 0.09523809523809523),
#  ('hey sensation', 0.09090909090909091),
#  ('hi sensation', 0.09090909090909091),
#  ('hey debonair', 0.1),
#  ('hi debonair', 0.1),
#  ('hi boisterous', 0.1),
#  ('hey exultant', 0.08333333333333333),
#  ('hey boisterous', 0.1),
#  ('hi exultant', 0.08333333333333333),
#  ('keen facts', 0.1),
#  ('dandy facts', 0.09090909090909091),
#  ('godly facts', 0.09090909090909091),
#  ('facts wizard', 0.09090909090909091),
#  ('fact wizard', 0.09090909090909091),
#  ('goodly facts', 0.09090909090909091),
#  ('letter s facts', 0.07142857142857142),
#  ('letter o facts', 0.08333333333333333),
#  ('hi gratification', 0.06666666666666667),
#  ('hi diversion', 0.1),
#  ('hey diversion', 0.1),
#  ('hey gratification', 0.06666666666666667),
#  ('hi providential', 0.07142857142857142),
#  ('hey providential', 0.07142857142857142),
#  ('hey propitious', 0.09090909090909091),
#  ('hey exhilaration', 0.07692307692307693),
#  ('hi exhilaration', 0.07692307692307693),
#  ('hi propitious', 0.09090909090909091),
#  ('titus trivia', 0.08333333333333333),
#  ('letter g facts', 0.07692307692307693),
#  ('letter y facts', 0.07692307692307693),
#  ('letter a facts', 0.08333333333333333),
#  ('letter v facts', 0.07692307692307693),
#  ('letter n facts', 0.07692307692307693),
#  ('letter i facts', 0.07692307692307693),
#  ('letter q facts', 0.07142857142857142),
#  ('letter x facts', 0.07142857142857142),
#  ('letter l facts', 0.07692307692307693),
#  ('letter p facts', 0.07692307692307693),
#  ('letter k facts', 0.07692307692307693),
#  ('letter t facts', 0.07692307692307693),
#  ('letter m facts', 0.07692307692307693),
#  ('letter u facts', 0.07142857142857142),
#  ('letter j facts', 0.07692307692307693),
#  ('letter e facts', 0.07692307692307693),
#  ('letter f facts', 0.07692307692307693),
#  ('letter c facts', 0.07692307692307693),
#  ('letter b facts', 0.07692307692307693),
#  ('strained facts', 0.08333333333333333),
#  ('mythical facts', 0.07692307692307693),
#  ('miracle facts', 0.07692307692307693),
#  ('darn facts', 0.1),
#  ('hot facts', 0.1),
#  ('reindeer names', 0.09090909090909091),
#  ('nepal date', 0.1),
#  ('africa quiz - four options trivia game!', 0.08823529411764706),
#  ('multiplication table', 0.05),
#  ('america quiz - four options trivia game!', 0.08823529411764706),
#  ('blackout drop', 0.08333333333333333),
#  ('fast facts', 0.1),
#  ('blackout dropper', 0.08333333333333333),
#  ('roll four dice', 0.09090909090909091),
#  ('flight facts', 0.1),
#  ('random skill!', 0.09090909090909091),
#  ('kerala facts', 0.08333333333333333),
#  ('snooker facts', 0.09090909090909091),
#  ('number wizard', 0.08333333333333333),
#  ('football terms', 0.09090909090909091),
#  ('football fun facts', 0.0625),
#  ('tongue twister', 0.09090909090909091),
#  ('cricket fact', 0.08333333333333333),
#  ('animal jokes', 0.09090909090909091),
#  ('counting dings', 0.09090909090909091),
#  ('musicals trivia', 0.0625),
#  ('element trivia', 0.07142857142857142),
#  ('kohli facts', 0.1),
#  ('joker facts', 0.1),
#  ('max facts', 0.1),
#  ('conversation starter', 0.05555555555555555),
#  ('mystery sound', 0.08333333333333333),
#  ('mary facts', 0.1),
#  ('planet fact', 0.08333333333333333),
#  ('random fact', 0.08333333333333333),
#  ('lucky number', 0.09090909090909091),
#  ('philly facts', 0.1),
#  ('happy fact', 0.1),
#  ("new year's facts", 0.07692307692307693),
#  ('new year facts', 0.07692307692307693),
#  ('christmas fact', 0.07692307692307693),
#  ('time traveller', 0.09090909090909091),
#  ('soccer fact', 0.1),
#  ('star fact', 0.1),
#  ('mink facts', 0.1),
#  ('america facts', 0.07142857142857142),
#  ('pakistani facts', 0.06666666666666667),
#  ('hanukkah fact', 0.08333333333333333),
#  ('space fact', 0.1),
#  ('number trivia', 0.07692307692307693),
#  ('famous quote', 0.09090909090909091),
#  ('inventor quiz', 0.07692307692307693),
#  ('quake facts', 0.1),
#  ('peanut butter facts', 0.0625),
#  ('dessert facts', 0.09090909090909091),
#  ('random facts!', 0.08333333333333333),
#  ('video games trivia', 0.058823529411764705),
#  ('hawks facts', 0.1),
#  ('indian state capitals', 0.1),
#  ('zodiac facts', 0.08333333333333333),
#  ('world record facts', 0.05555555555555555),
#  ('africa capitals quiz', 0.047619047619047616),
#  ('useless fact', 0.08333333333333333),
#  ('category game', 0.07692307692307693),
#  ('norris facts', 0.09090909090909091),
#  ('arizona fact', 0.07692307692307693),
#  ('avocado fact', 0.07692307692307693),
#  ('african capitals quiz', 0.047619047619047616),
#  ('world capitals quiz', 0.05555555555555555),
#  ('scooby facts', 0.09090909090909091),
#  ('horse trivia', 0.09090909090909091),
#  ('bird trivia', 0.09090909090909091),
#  ('dungeon roller', 0.09090909090909091),
#  ('video game trivia', 0.058823529411764705),
#  ('u.s. presidents quiz', 0.05555555555555555),
#  ('cancer fact', 0.09090909090909091),
#  ('element quiz', 0.07692307692307693),
#  ('sun trivia', 0.1),
#  ('nerd trivia', 0.1),
#  ('wild animal facts', 0.05555555555555555),
#  ('periodical table quiz', 0.09523809523809523),
#  ('birds trivia', 0.09090909090909091),
#  ('animals trivia', 0.07142857142857142),
#  ('elephant trivia', 0.07142857142857142),
#  ('candy facts', 0.09090909090909091),
#  ('united states rivers trivia', 0.038461538461538464),
#  ('wonderful penguin facts', 0.043478260869565216),
#  ('cat trivia', 0.1),
#  ('dream facts', 0.09090909090909091),
#  ('poker facts', 0.1),
#  ('lion facts', 0.1),
#  ('bunny facts', 0.1),
#  ('park facts', 0.1),
#  ('fact fact', 0.1),
#  ('kerala fact', 0.08333333333333333),
#  ('avocado facts', 0.07692307692307693),
#  ('star trek fact', 0.06666666666666667),
#  ('money facts', 0.1),
#  ('tango facts', 0.09090909090909091),
#  ('mass facts', 0.1),
#  ('world capital quiz', 0.05555555555555555),
#  ('random funny facts', 0.058823529411764705),
#  ('fun math fact', 0.07692307692307693),
#  ('state facts', 0.09090909090909091),
#  ('india fact', 0.09090909090909091),
#  ('galaxy fact', 0.07692307692307693),
#  ('indian foods', 0.09090909090909091),
#  ('indian festival', 0.0625),
#  ('funny fact', 0.1),
#  ('film quote', 0.1),
#  ('national anthems', 0.07142857142857142),
#  ('zodiac fact', 0.08333333333333333),
#  ('states facts', 0.09090909090909091),
#  ('tax facts', 0.1),
#  ('pakistan facts', 0.06666666666666667),
#  ('mystery sounds', 0.08333333333333333),
#  ('environment facts', 0.058823529411764705),
#  ('united states river trivia', 0.038461538461538464),
#  ('norse facts', 0.09090909090909091),
#  ('dark facts', 0.1),
#  ('roll fair dice', 0.09090909090909091),
#  ('tech trivia', 0.1),
#  ('numbers game', 0.1),
#  ('archery facts', 0.09090909090909091),
#  ('sikhs facts', 0.1),
#  ('flower fact', 0.1),
#  ('science fact', 0.09090909090909091),
#  ('animal trivia', 0.07142857142857142),
#  ('fun math facts', 0.07692307692307693),
#  ('tip calculator', 0.06666666666666667),
#  ('yarn facts', 0.1),
#  ('ryan facts', 0.1),
#  ('throne facts', 0.1),
#  ('scuba facts', 0.09090909090909091),
#  ('film facts', 0.1),
#  ('alternative facts', 0.06666666666666667),
#  ('light facts', 0.1),
#  ('tongue twisters', 0.09090909090909091),
#  ('guitar chord', 0.09090909090909091),
#  ('periodic table quiz', 0.09523809523809523),
#  ('sport quiz', 0.09090909090909091),
#  ('cal trivia', 0.1),
#  ('what the fact?', 0.08333333333333333),
#  ('geography facts', 0.07142857142857142),
#  ('history fact', 0.08333333333333333),
#  ('quick facts', 0.1),
#  ('tick trivia', 0.1),
#  ('hero facts', 0.1),
#  ('fun trivia', 0.1),
#  ('fortune cookies', 0.08333333333333333),
#  ('val trivia', 0.1),
#  ('space facts!', 0.1),
#  ('venice facts', 0.09090909090909091),
#  ('incredible india facts', 0.043478260869565216),
#  ('honeybee facts', 0.07692307692307693),
#  ('us president quiz', 0.05555555555555555),
#  ('fun sport facts', 0.0625),
#  ('film quotes', 0.1),
#  ('fun cat facts', 0.07142857142857142),
#  ('titan trivia', 0.08333333333333333),
#  ('world records facts', 0.05555555555555555),
#  ('south africa facts', 0.058823529411764705),
#  ('geography fact', 0.07142857142857142),
#  ('football fun fact', 0.0625),
#  ('horror trivia', 0.09090909090909091),
#  ('cosmetics facts', 0.06666666666666667),
#  ('sleep sounds: womb sounds', 0.1),
#  ('ocean sounds', 0.1),
#  ('rain sounds', 0.1),
#  ('times table', 0.09090909090909091),
#  ('bedtime stories', 0.07692307692307693),
#  ('magic word', 0.1),
#  ('numbers wizard', 0.08333333333333333),
#  ('number games', 0.1),
#  ('daily affirmations', 0.07142857142857142),
#  ('random quote', 0.08333333333333333),
#  ('doggy facts', 0.1),
#  ('beagle facts', 0.09090909090909091),
#  ('soothing sounds: relax, study or meditate', 0.08333333333333333),
#  ('new years resolution', 0.05555555555555555),
#  ("new year's resolution", 0.05555555555555555),
#  ('new year resolutions', 0.05555555555555555),
#  ('island sounds for sleep, relaxation, and focus', 0.07317073170731707),
#  ('rain sounds for sleep, relaxation, and focus', 0.075),
#  ('ocean sounds for sleep, relaxation, and focus', 0.07317073170731707),
#  ('decision maker', 0.08333333333333333),
#  ('w. a. v. a. a. m.', 0.1),
#  ('w. a. v. a. f. m.', 0.1),
#  ('jain assistant', 0.08333333333333333),
#  ('jain trivia', 0.1),
#  ('random scale', 0.09090909090909091),
#  ('conversation starters', 0.05555555555555555),
#  ('daily affirmation', 0.07142857142857142),
#  ('movie rating', 0.09090909090909091),
#  ('hollywood facts', 0.07692307692307693),
#  ('movie ratings', 0.09090909090909091),
#  ('sleep sounds: clock sound', 0.047619047619047616),
#  ('relaxing sleep sounds: fan sounds', 0.06896551724137931),
#  ('sleep sounds: snoring sound', 0.043478260869565216),
#  ('z93', 0.1),
#  ('sleep sounds: owl sounds', 0.1),
#  ('hot 104.5', 0.1),
#  ('do motivation', 0.07692307692307693),
#  ('did motivation', 0.07692307692307693),
#  ('dude motivation', 0.07692307692307693),
#  ('forest sounds', 0.08333333333333333),
#  ('thunder sounds', 0.09090909090909091),
#  ('sound sleep', 0.1),
#  ('heavy rain sounds', 0.07142857142857142),
#  ('water drop sounds', 0.06666666666666667),
#  ('sleep sound: rainforest sounds', 0.038461538461538464),
#  ('light rain sounds', 0.07692307692307693),
#  ('tamil comedies', 0.07692307692307693),
#  ('life 107.1', 0.09090909090909091),
#  ('beach 104', 0.0625),
#  ('wind sounds', 0.1),
#  ('indian national anthem', 0.05),
#  ('joy 107-1', 0.09523809523809523),
#  ('hot 107.5', 0.09090909090909091),
#  ('mix 101.5', 0.047619047619047616),
#  ('hot 105.5', 0.1),
#  ('magic 104.5', 0.09090909090909091),
#  ('103.7 the hawk', 0.08),
#  ('national anthem', 0.07142857142857142),
#  ('b93', 0.1),
#  ('mix 104.3', 0.09523809523809523),
#  ('mix 105.3', 0.09523809523809523),
#  ('q106.9', 0.09523809523809523),
#  ('i107-1', 0.09090909090909091),
#  ('liberia national anthem', 0.09523809523809523),
#  ('iraq national anthem', 0.05555555555555555),
#  ('west congo national anthem', 0.08333333333333333),
#  ('east congo national anthem', 0.08333333333333333),
#  ('zambia national anthem', 0.05),
#  ('iran national anthem', 0.05555555555555555),
#  ('gambia national anthem', 0.05),
#  ('algeria national anthem', 0.09523809523809523),
#  ('nigeria national anthem', 0.09523809523809523),
#  ('ireland national anthem', 0.05),
#  ('syria national anthem', 0.1),
#  ('iceland national anthem', 0.05),
#  ('jordan national anthem', 0.1),
#  ('poland national anthem', 0.1),
#  ('india national anthem', 0.05),
#  ('austria national anthem', 0.1),
#  ('georgia national anthem', 0.1),
#  ('magic 104.9', 0.09090909090909091),
#  ('sleep sounds: wolf sounds', 0.09523809523809523),
#  ('sleep sounds: truck sounds', 0.09523809523809523),
#  ('sleep sounds: loon sounds', 0.09523809523809523),
#  ('sleep sounds: flute sounds', 0.09523809523809523),
#  ('alt 101.9', 0.1),
#  ('b104', 0.0625),
#  ('magic 102.5', 0.09523809523809523),
#  ('magic 102.9', 0.09523809523809523),
#  ('q 106.1', 0.09523809523809523),
#  ('96.9 the eagle', 0.1),
#  ('e93', 0.1),
#  ('kicks 101.5', 0.047619047619047616),
#  ('sleep sounds: whale sounds', 0.09523809523809523),
#  ('96.1 the eagle', 0.1),
#  ('103.7 the peak', 0.08),
#  ('hot 107.9', 0.09090909090909091),
#  ('sleep sounds: shower sounds', 0.1),
#  ('tamil comedy', 0.07692307692307693),
#  ('sleep sounds: rain sounds', 0.047619047619047616),
#  ('sleep sounds: rainforest sounds', 0.038461538461538464),
#  ('sleep sounds: cat sounds', 0.1),
#  ('sleep sounds: clock sounds', 0.047619047619047616),
#  ('hot 101.9', 0.1),
#  ('sleep sounds: train sounds', 0.047619047619047616),
#  ('radios mystery theater', 0.05263157894736842),
#  ('sleep sounds: fan sounds', 0.1),
#  ('radio mystery theater', 0.05263157894736842),
#  ('india news', 0.1),
#  ('indian news', 0.1),
#  ('american election', 0.058823529411764705),
#  ('american elections', 0.058823529411764705),
#  ('animal joke', 0.09090909090909091),
#  ('random dad jokes', 0.06666666666666667),
#  ('kids advice', 0.1),
#  ('magic eight ball', 0.07692307692307693),
#  ('happy quotes', 0.1),
#  ('summer facts', 0.1),
#  ('random dad joke', 0.06666666666666667),
#  ('super heroes', 0.1),
#  ('christmas cracker jokes', 0.05555555555555555),
#  ('christmas cracker joke', 0.05555555555555555),
#  ('fart sounds', 0.1),
#  ('kelly facts', 0.1),
#  ('dumb facts', 0.1),
#  ('morning complements', 0.05555555555555555),
#  ('morning compliments', 0.05555555555555555),
#  ('holiday calendar', 0.06666666666666667),
#  ('happy facts', 0.1),
#  ('parent facts', 0.08333333333333333),
#  ('daily fact', 0.1),
#  ('alternative fact', 0.06666666666666667),
#  ('magic hate ball', 0.07692307692307693),
#  ('tyler facts', 0.1),
#  ('donald trump fact', 0.05555555555555555),
#  ('lucky numbers', 0.09090909090909091),
#  ('magic 8-ball', 0.07692307692307693),
#  ('smart home', 0.1),
#  ('holidays calendar', 0.06666666666666667),
#  ('rain facts', 0.1),
#  ('decisionmaker', 0.08333333333333333),
#  ('tips calculator', 0.06666666666666667),
#  ('brilliant smart', 0.07142857142857142),
#  ('smarter home', 0.1),
#  ('auckland guide', 0.1),
#  ('asheville guide', 0.1),
#  ('nashville guide', 0.1),
#  ('time travel', 0.09090909090909091),
#  ('snow report for boler mountain', 0.07407407407407407),
#  ('snow report for snow king', 0.09090909090909091),
#  ('snow report for duck mountain', 0.08),
#  ('snow report for stowe mountain resort', 0.09375),
#  ('snow report for deer valley', 0.08695652173913043),
#  ('snow report for sundance mountain', 0.06896551724137931),
#  ('snow report for burke mountain', 0.07692307692307693),
#  ('snow report for blue mountain', 0.07692307692307693),
#  ('snow report for elk mountain', 0.07692307692307693),
#  ('snow report for beech mountain', 0.07692307692307693),
#  ('snow report for maverick mountain', 0.07142857142857142),
#  ('snow report for gore mountain', 0.08),
#  ('snow report for willard mountain', 0.07407407407407407),
#  ('snow report for magic mountain', 0.07142857142857142),
#  ('snow report for wild mountain', 0.07407407407407407),
#  ('snow report for beaver mountain', 0.07692307692307693),
#  ('snow report for song mountain', 0.08),
#  ('snow report for lee canyon', 0.07692307692307693),
#  ('snow report for cannon mountain', 0.03571428571428571),
#  ('snow report for silver mountain', 0.07407407407407407),
#  ('snow report for baker mountain', 0.07692307692307693),
#  ('snow report for apple mountain', 0.07407407407407407),
#  ('snow report for pine mountain', 0.07407407407407407),
#  ('snow report for mad river', 0.08695652173913043),
#  ('snow report for royal mountain', 0.07692307692307693),
#  ('snow report for loon mountain', 0.04),
#  ('snow report for sundown mountain', 0.06896551724137931),
#  ('snow report for sun valley', 0.08695652173913043),
#  ('snow report for bay mountain', 0.07692307692307693),
#  ('snow report for alpine mountain', 0.07407407407407407),
#  ('snow report for black mountain', 0.07692307692307693),
#  ('snow report for soldier mountain', 0.07407407407407407),
#  ('snow report for powder ridge', 0.08695652173913043),
#  ('snow report for oak mountain', 0.08),
#  ('snow report for kelly canyon', 0.07692307692307693),
#  ('snow report for snow ridge', 0.09090909090909091),
#  ('snow report for june mountain', 0.04),
#  ('snow report for bear mountain', 0.08),
#  ('snow report for snow valley', 0.08695652173913043),
#  ('snow report for red river', 0.08695652173913043),
#  ('snow report for powder king', 0.08695652173913043),
#  ('snow report for castle mountain', 0.07407407407407407),
#  ('snow report for mt buller', 0.08333333333333333),
#  ('snow report for red mountain resort', 0.09375),
#  ('snow report for aspen mountain', 0.07407407407407407),
#  ('snow report for bear valley', 0.08695652173913043),
#  ('snow report for badger mountain', 0.07692307692307693),
#  ('snow report for mt baker', 0.08333333333333333),
#  ('snow report for canyon mountain', 0.03571428571428571)]

# %%
    
    min01 = [(d, sk1, sk2) for (d, sk1, sk2) in phondist if d <= 0.1 and d!=0]
    total = 0
    for m in min01:
        name1,name2 = m[1],m[2]
        total += skillnamecount_d[name1]
        total += skillnamecount_d[name2]
    print('There are ', len(min01), 'skills within a ld of 0.1, addding a total of hits ', total, '(',total/totalanalysis,'%)')
    
    min02 = [(d, sk1, sk2) for (d, sk1, sk2) in phondist if d <= 0.2 and d!=0]
    total = 0
    for m in min02:
        name1,name2 = m[1],m[2]
        total += skillnamecount_d[name1]
        total += skillnamecount_d[name2]
    print('There are ', len(min02), 'skills within a ld of 0.1, addding a total of hits ', total, '(',total/totalanalysis,'%)')
# Out:
# Loaded json for  AU  : PhonDict/AU.json
# Loaded json for  CA  : PhonDict/CA.json
# Loaded json for  IN  : PhonDict/IN.json
# Loaded json for  UK  : PhonDict/UK.json
# Loaded json for  US  : PhonDict/US.json
# Studying market AU
# Total unique skill names  121344831
# There are  455 skills within a ld of 0.1, addding a total of hits  1609 ( 1.3259732505622757e-05 %)
# There are  6325 skills within a ld of 0.1, addding a total of hits  18627 ( 0.00015350468451350846 %)
# Studying market CA
# Total unique skill names  139653828
# There are  724 skills within a ld of 0.1, addding a total of hits  2199 ( 1.5746077508165404e-05 %)
# There are  8325 skills within a ld of 0.1, addding a total of hits  23105 ( 0.00016544480255850918 %)
# Studying market IN
# Total unique skill names  138619575
# There are  595 skills within a ld of 0.1, addding a total of hits  6029 ( 4.3493135799904164e-05 %)
# There are  6864 skills within a ld of 0.1, addding a total of hits  30082 ( 0.0002170111977330763 %)
# Studying market UK
# Total unique skill names  180509500
# There are  765 skills within a ld of 0.1, addding a total of hits  2484 ( 1.3761048587470465e-05 %)
# There are  6885 skills within a ld of 0.1, addding a total of hits  21212 ( 0.00011751182070749738 %)
# Studying market US
# Total unique skill names  708140161
# There are  2110 skills within a ld of 0.1, addding a total of hits  5941 ( 8.389582073145545e-06 %)
# There are  23656 skills within a ld of 0.1, addding a total of hits  58522 ( 8.264183169241265e-05 %)

# %%
phondist
# Out:
# [[0.15384615384615385,
#   'snow report for blue mountain',
#   'snow report for turner mountain'],
#  [0, 'cool physics facts', 'cool physics facts'],
#  [0, 'red dead hunter', 'red dead hunter'],
#  [0.3, 'scout facts', 'night facts'],
#  [0.2727272727272727, 'lemur facts', 'beavers facts'],
#  [0.3, 'ocean facts', 'money facts'],
#  [0.2631578947368421, 'chad national anthem', 'morocco national anthem'],
#  [0, 'rebellious chicks', 'rebellious chicks'],
#  [0,
#   'michael guerrero - san antonio real estate',
#   'michael guerrero - san antonio real estate'],
#  [0.3, 'number fact', 'number dex'],
#  [0.2, 'snow report for lee canyon', 'snow report for loon mountain'],
#  [0.2916666666666667,
#   'snow fact number four card',
#   'rain fact number six card'],
#  [0.25925925925925924, '101.7 the hammer', '107.7 the bone'],
#  [0.2727272727272727,
#   'argentina fact number seven card',
#   'space station fact number seven card'],
#  [0.2857142857142857, 'tennessee facts part ten', 'ohio facts part ten'],
#  [0.23684210526315788,
#   'winning numbers for arkansas cash 4 evening',
#   'winning numbers for tri-state pick 4 evening'],
#  [0.2692307692307692,
#   'morocco fact number two card',
#   'pineapple fact number two card'],
#  [0.18421052631578946,
#   'winning numbers for florida pick 4 midday',
#   'winning numbers for florida pick 5 evening'],
#  [0.2962962962962963,
#   'fire fact number sixteen card',
#   'snow fact number eleven card'],
#  [0.25, '101.1 the river', '103.1 the wave'],
#  [0.2916666666666667,
#   'rain fact number nine card',
#   'earth fact number thirteen card'],
#  [0.2916666666666667,
#   'math fact number two card',
#   'wind fact number three card'],
#  [0.3,
#   'satellite fact number nineteen card',
#   'hurricane fact number fourteen card'],
#  [0.2222222222222222, 'remember when 1920', 'remember when 1944'],
#  [0.2962962962962963,
#   'lightning fact number eighteen card',
#   'waterfall fact number ten card'],
#  [0.15384615384615385,
#   'lemon fact number six card',
#   'rain fact number six card'],
#  [0.2777777777777778, 'wicked local canton', 'wicked local stoneham'],
#  [0.2916666666666667,
#   'fire fact number six card',
#   'earth fact number ten card'],
#  [0.23076923076923078, 'cat translator', 'bird translator'],
#  [0, 'my last payment', 'my last payment'],
#  [0.2727272727272727, 'fishing quiz', 'physics quiz'],
#  [0.3, 'coffee facts', 'fiji facts'],
#  [0, 'the exotic butters', 'the exotic butters'],
#  [0.3, 'shark facts', 'golf facts'],
#  [0.1875,
#   'mango fact number seventeen card',
#   'galaxy fact number seventeen card'],
#  [0.2777777777777778, 'valentines day facts', "valentine's day quiz"],
#  [0.15, 'wicked local hamilton', 'wicked local milton'],
#  [0.2413793103448276, 'remember when 1900', 'remember when 1954'],
#  [0.3, 'sun facts', 'fun factory'],
#  [0, 'royal family news', 'royal family news'],
#  [0.2857142857142857, 'philosophy facts', 'monopoly facts'],
#  [0.1724137931034483,
#   'carrot fact number sixteen card',
#   'carrot fact number seven card'],
#  [0.2631578947368421, 'togo national anthem', 'bhutan national anthem'],
#  [0.3, 'days fact', 'amaze facts'],
#  [0.2631578947368421, 'brunei national anthem', 'laos national anthem'],
#  [0.23809523809523808, 'belarus national anthem', 'malawi national anthem'],
#  [0.2916666666666667,
#   'snow report for tahoe donner',
#   'snow report for red river'],
#  [0.25, 'teen guide', 'reno guide'],
#  [0.25, 'letter e facts', 'turkey facts'],
#  [0.3, 'dash facts', 'dino facts'],
#  [0.3076923076923077,
#   'austria fact number five card',
#   'lightning fact number one card'],
#  [0.2727272727272727, 'migraine buddy', 'train buddy'],
#  [0.2777777777777778, 'college football facts', 'college football news'],
#  [0.28, 'star fact number eighteen card', 'math fact number three card'],
#  [0.3, 'sleep facts', 'suits facts'],
#  [0.3, 'state facts', 'state jokes'],
#  [0.2631578947368421, 'wicked local medford', 'wicked local westborough'],
#  [0.3076923076923077, 'candy 95', 'magic 95'],
#  [0.2608695652173913,
#   'turkey fact number two card',
#   'rain fact number eight card'],
#  [0.29411764705882354, 'straight talk podcast', 'couch talk podcast'],
#  [0.3, 'ku facts', 'bluey facts'],
#  [0.26666666666666666,
#   'argentina fact number six card',
#   'pineapple fact number six card'],
#  [0.19047619047619047, 'mindset 360', 'mindset 365'],
#  [0.2222222222222222, 'up facts', 'rap facts'],
#  [0.2, 'hot 93.1', 'hot 99.1'],
#  [0.2222222222222222,
#   'coconut fact number five card',
#   'protein fact number five card'],
#  [0.30434782608695654,
#   'time fact number nine card',
#   'cloud fact number eight card'],
#  [0.11428571428571428,
#   'united states fact number one card',
#   'united states fact number thirteen card'],
#  [0.3076923076923077,
#   'protein fact number three card',
#   'orange fact number one card'],
#  [0.3, 'duck facts', 'mix facts'],
#  [0.3076923076923077,
#   'spain fact number eighteen card',
#   'austria fact number one card'],
#  [0.1111111111111111, 'remember when 1991', 'remember when 1941'],
#  [0.3, 'color facts', 'beaver facts'],
#  [0, 'chameleon facts home card', 'chameleon facts home card'],
#  [0, 'could you guess', 'could you guess'],
#  [0, 'reach on air', 'reach on air'],
#  [0, 'global news politics', 'global news politics'],
#  [0.28, 'snow report for buena vista', 'snow report for sun valley'],
#  [0.2916666666666667, '104.9 the fox', '101.9 the wave'],
#  [0.17647058823529413, 'czech national anthem', 'peru national anthem'],
#  [0.3, 'perk me up', 'pump me up'],
#  [0, 'corn fact number ten card', 'corn fact number ten card'],
#  [0.3, 'love facts', 'drug facts'],
#  [0, 'best beatles quotes', 'best beatles quotes'],
#  [0.29411764705882354, 'mistry space facts', "nick's space facts"],
#  [0.18518518518518517,
#   'austria fact number eighteen card',
#   'turkey fact number eighteen card'],
#  [0.25, 'corn fact number ten card', 'math fact number one card'],
#  [0.25, 'pigeon facts', 'poland facts'],
#  [0.14285714285714285,
#   'banana fact number thirteen card',
#   'banana fact number nine card'],
#  [0.3, 'neon facts', 'seal facts'],
#  [0.3076923076923077,
#   'protein fact number one card',
#   'hurricane fact number eight card'],
#  [0.3, 'venezuela fact number six card', 'astronaut fact number six card'],
#  [0.3076923076923077,
#   'flood fact number four card',
#   'hurricane fact number nine card'],
#  [0.3076923076923077, 'capital facts', 'turtle facts!'],
#  [0.2727272727272727, 'car facts', 'cobra facts'],
#  [0.16666666666666666,
#   'fire fact number two card',
#   'thunder fact number two card'],
#  [0.2916666666666667,
#   'math fact number two card',
#   'star fact number four card'],
#  [0.3, 'space facts!', 'pooch facts'],
#  [0.3076923076923077, 'cell phone facts', 'fake fun facts'],
#  [0.2916666666666667,
#   'spain fact number ten card',
#   'cloud fact number three card'],
#  [0, 'hello serene', 'hello serene'],
#  [0, 'fire safety tip of the day', 'fire safety tip of the day'],
#  [0.21052631578947367, 'flood facts home card', 'spain facts home card'],
#  [0.23529411764705882, 'amazing ghost facts', 'amazing fish facts'],
#  [0.2857142857142857, 'somalia national anthem', 'sweden national anthem'],
#  [0.2692307692307692,
#   'belgium fact number three card',
#   'flood fact number nine card'],
#  [0.2222222222222222, 'good facts', 'toad facts'],
#  [0, 'front end web daily', 'front end web daily'],
#  [0, 'fact factory', 'fact factory'],
#  [0, "valentine's day", "valentine's day"],
#  [0.25, 'scary sound: halloween sounds', 'ghost sounds: halloween sounds'],
#  [0.25,
#   'winning numbers for illinois pick 3 midday',
#   'winning numbers for virginia pick 3 day'],
#  [0.3, 'business coach', 'business elf'],
#  [0.16666666666666666,
#   'spain fact number sixteen card',
#   'lightning fact number sixteen card'],
#  [0.3, 'queen facts', 'aussie facts'],
#  [0.21052631578947367, 'wales facts home card', 'china facts home card'],
#  [0.2, 'banana fact number twenty card', 'tornado fact number twenty card'],
#  [0.3076923076923077,
#   'carrot fact number two card',
#   'protein fact number five card'],
#  [0,
#   'kristopher benveniste - brentwood real estate',
#   'kristopher benveniste - brentwood real estate'],
#  [0.13636363636363635,
#   'born on november eighteen',
#   'born on november nineteen'],
#  [0.14285714285714285, 'the border 106.7', 'the river 106.7'],
#  [0.24, 'snow report for falcon ridge', 'snow report for powder ridge'],
#  [0.13043478260869565,
#   'ambient sounds zombie beach',
#   'ambient sounds zombie rain'],
#  [0.2727272727272727, 'kitten facts', 'sun facts'],
#  [0.18181818181818182, 'random teller', 'random letter'],
#  [0.2222222222222222,
#   'protein fact number six card',
#   'mango fact number six card'],
#  [0.25, 'coconut fact number two card', 'television fact number two card'],
#  [0.3076923076923077,
#   'snow report for holiday valley',
#   'snow report for mont avila'],
#  [0.3, 'fish facts', 'mix facts'],
#  [0.2692307692307692,
#   'banana fact number nine card',
#   'belgium fact number five card'],
#  [0.12, '100.3 the wolf', '106.3 the wolf'],
#  [0.2222222222222222, 'remember when 1933', 'remember when 1959'],
#  [0.23076923076923078, 'medical facts', 'medical jokes'],
#  [0.19230769230769232, 'remember when 1982', 'remember when 1958'],
#  [0.3, 'jolly facts', 'cherry facts'],
#  [0.06896551724137931,
#   'television fact number nine card',
#   'television fact number one card'],
#  [0.1724137931034483,
#   'tornado fact number four card',
#   'tornado fact number twelve card'],
#  [0.2222222222222222,
#   'top grossing mac apps - mexico unofficial',
#   'top grossing mac apps - australia unofficial'],
#  [0.2727272727272727, 'sulfur facts', 'duluth facts'],
#  [0.3, 'kid facts', 'acne facts'],
#  [0.3, 'duck facts', 'quake facts'],
#  [0.2727272727272727, 'idaho facts', 'duck facts'],
#  [0.3076923076923077,
#   'time fact number fourteen card',
#   'morocco fact number four card'],
#  [0.2857142857142857,
#   'lemon fact number fifteen card',
#   'lightning fact number eighteen card'],
#  [0.2, 'unofficial vader facts', 'unofficial dodgers facts'],
#  [0.21428571428571427, 'funny horse jokes', 'funny dog jokes'],
#  [0.26666666666666666, '95 country', '96 country'],
#  [0.13043478260869565, 'kick 106.7', 'i106.7'],
#  [0.13043478260869565,
#   'math fact number eight card',
#   'math fact number five card'],
#  [0.3, 'mummy facts', 'butt facts'],
#  [0.15384615384615385,
#   'snow report for badger mountain',
#   'snow report for gore mountain'],
#  [0.3, 'my facts', 'wind facts'],
#  [0.3076923076923077,
#   'spain fact number seven card',
#   'fire fact number six card'],
#  [0.24, 'country 103.7', 'mix 103.7'],
#  [0.2631578947368421, 'wicked local canton', 'wicked local watertown'],
#  [0.20689655172413793,
#   'snow report for mccauley mountain',
#   'snow report for sundance mountain'],
#  [0.16666666666666666, 'maine facts home card', 'fish facts home card'],
#  [0.20689655172413793,
#   'lightning fact number eleven card',
#   'morocco fact number eleven card'],
#  [0, 'about indian states', 'about indian states'],
#  [0, 'australia national anthem', 'australia national anthem'],
#  [0.28, 'rain fact number twelve card', 'time fact number five card'],
#  [0, '98.1 the river', '98.1 the river'],
#  [0.16666666666666666, '80s music trivia', "80's movie trivia"],
#  [0.2916666666666667, '105.9 the hog', '101.9 the wolf'],
#  [0.3, 'awesome facts', 'dream facts'],
#  [0.2916666666666667,
#   'snow report for big boulder',
#   'snow report for red lodge'],
#  [0, 'education quotes', 'education quotes'],
#  [0, 'letter linker', 'letter linker'],
#  [0, 'party dice', 'party dice'],
#  [0.25925925925925924,
#   'england fact number nine card',
#   'rainbow fact number nine card'],
#  [0, 'effingham news talk', 'effingham news talk'],
#  [0, 'sauk valley now', 'sauk valley now'],
#  [0, 'y 101', 'y 101'],
#  [0.13043478260869565,
#   'earth fact number four card',
#   'time fact number four card'],
#  [0.1875, 'cool music facts', 'fun music facts'],
#  [0.3076923076923077,
#   'turkey fact number six card',
#   'nuclear fact number one card'],
#  [0, 'snake numbers', 'snake numbers'],
#  [0, 'number adventures', 'number adventures'],
#  [0, 'tiny fox', 'tiny fox'],
#  [0.2727272727272727, 'wizard facts', 'will facts'],
#  [0.25, 'food fact', 'good fact'],
#  [0.30434782608695654, 'indiana facts part one', 'louisiana facts part four'],
#  [0.2222222222222222, 'mole facts', 'boat facts'],
#  [0, 'the agency', 'the agency'],
#  [0, 'world rhymes', 'world rhymes'],
#  [0, 'the hitz', 'the hitz'],
#  [0.3, 'array radio', 'vapor radio'],
#  [0.2727272727272727, 'hi allegro', 'hola allegro'],
#  [0.20833333333333334, '105.3 the bat', '104-3 the breeze'],
#  [0.2727272727272727, 'sunny 106.9', 'eagle 106.5'],
#  [0.3, 'bat facts', 'bonner facts'],
#  [0.3, 'ledo smart', 'zero smart'],
#  [0.27586206896551724, 'remember when 1900', 'remember when 1995'],
#  [0.2916666666666667,
#   'bald eagle facts home card',
#   'chameleon facts home card'],
#  [0.21052631578947367, 'beaver facts home card', 'cloud facts home card'],
#  [0.22580645161290322,
#   'england fact number sixteen card',
#   'satellite fact number sixteen card'],
#  [0.09090909090909091,
#   'space station fact number three card',
#   'space station fact number thirteen card'],
#  [0.2222222222222222, 'ant facts', 'fit facts'],
#  [0.3, 'zambia national anthem', 'egypt national anthem'],
#  [0.2857142857142857, 'wild 105-5', 'hot 104.5'],
#  [0.30434782608695654,
#   'crocodile facts home card',
#   'tennessee facts home card'],
#  [0.1875, 'your morning routine', 'my morning routine'],
#  [0.2857142857142857,
#   'fast food fact number three card',
#   'hurricane fact number three card'],
#  [0.11764705882352941, 'motivation sounds', 'motivational sounds'],
#  [0.24, 'snow report for mt baker', 'snow report for mont avila'],
#  [0.09523809523809523, 'oregon facts part nine', 'oregon facts part one'],
#  [0.2727272727272727, 'montana facts home card', 'germany facts home card'],
#  [0.2857142857142857, 'hurricane facts home card', 'cheetah facts home card'],
#  [0.25, 'turkey fact number nine card', 'money fact number three card'],
#  [0.14285714285714285,
#   'galaxy fact number eighteen card',
#   'galaxy fact number four card'],
#  [0.29411764705882354,
#   'winning numbers for connecticut cash 5',
#   'winning numbers for new york take 5'],
#  [0.3076923076923077, 'local events', 'travel events'],
#  [0.15384615384615385,
#   'spain fact number five card',
#   'hurricane fact number five card'],
#  [0.27586206896551724,
#   'carrot fact number sixteen card',
#   'pineapple fact number six card'],
#  [0.2857142857142857, 'denmark facts', 'fun shark facts'],
#  [0.2631578947368421, 'syria national anthem', 'japan national anthem'],
#  [0.25, 'suriname national anthem', 'sweden national anthem'],
#  [0.3, 'snake facts', 'bike facts'],
#  [0.17857142857142858,
#   'snow report for castle mountain',
#   'snow report for maverick mountain'],
#  [0.3076923076923077,
#   'snow fact number eleven card',
#   'morocco fact number ten card'],
#  [0.3076923076923077,
#   'lightning fact number three card',
#   'thunder fact number two card'],
#  [0.2, 'math fact number seven card', 'math fact number twelve card'],
#  [0.3076923076923077,
#   'wind fact number seven card',
#   'star fact number five card'],
#  [0.25, 'earth fact number ten card', 'cloud fact number one card'],
#  [0.2222222222222222, 'sung facts', 'pun facts'],
#  [0.21428571428571427,
#   'mushroom fact number seven card',
#   'wind fact number seven card'],
#  [0.3, 'radio chaser', 'radio sai'],
#  [0.25, 'star fact number twelve card', 'morocco fact number twenty card'],
#  [0.2608695652173913, 'ireland facts home card', 'colombia facts home card'],
#  [0.2916666666666667,
#   'rain fact number six card',
#   'time fact number four card'],
#  [0.23809523809523808, 'albania national anthem', 'india national anthem'],
#  [0.2962962962962963,
#   'lemon fact number twelve card',
#   'protein fact number ten card'],
#  [0.25, 'cameroon national anthem', 'gabon national anthem'],
#  [0.23076923076923078,
#   'snow report for bolton valley',
#   'snow report for bretton woods'],
#  [0.3076923076923077, 'dolphins facts', 'falcon facts'],
#  [0.21052631578947367, 'beaver facts home card', 'crab facts home card'],
#  [0.2222222222222222, 'wicked local plymouth', 'wicked local whitman'],
#  [0.2857142857142857,
#   'rain fact number eleven card',
#   'orange fact number fifteen card'],
#  [0, 'cooking temperatures', 'cooking temperatures'],
#  [0, 'perfect egg', 'perfect egg'],
#  [0, 'huntsville on tap', 'huntsville on tap'],
#  [0, 'brookfield patch', 'brookfield patch'],
#  [0, 'seven boom', 'seven boom'],
#  [0, 'pink noise', 'pink noise'],
#  [0, 'miles taco facts', 'miles taco facts'],
#  [0.3, 'key facts', 'delhi facts'],
#  [0, 'shape up', 'shape up'],
#  [0, 'inspirational motivator', 'inspirational motivator'],
#  [0.2727272727272727, 'forest sound', 'horse sound'],
#  [0.08695652173913043,
#   'earth fact number four card',
#   'math fact number four card'],
#  [0.2608695652173913,
#   'wind fact number two card',
#   'time fact number one card'],
#  [0.2413793103448276,
#   'lemon fact number thirteen card',
#   'belgium fact number nineteen card'],
#  [0.2857142857142857, 'belarus national anthem', 'burundi national anthem'],
#  [0.18518518518518517,
#   'lemon fact number twelve card',
#   'turkey fact number twelve card'],
#  [0.2962962962962963,
#   'carrot fact number ten card',
#   'pineapple fact number three card'],
#  [0.23333333333333334,
#   'england fact number eighteen card',
#   'switzerland fact number ten card'],
#  [0.3, 'new hope baptist church', 'pine grove baptist church'],
#  [0.3, 'delhi facts', 'will facts'],
#  [0.19230769230769232,
#   'fast fact president regan',
#   'fast fact president kennedy'],
#  [0, 'agility voice', 'agility voice'],
#  [0, 'designer excuses', 'designer excuses'],
#  [0.25, 'k102.5', 'kool 101.5'],
#  [0, 'sleep waves', 'sleep waves'],
#  [0.25925925925925924,
#   'waterfall fact number five card',
#   'thunder fact number five card'],
#  [0, 'make me chuckle', 'make me chuckle'],
#  [0, 'the health code', 'the health code'],
#  [0, 'doc rogers', 'doc rogers'],
#  [0.3, 'g 105.1', 'q105.5'],
#  [0.3076923076923077, 'delaware facts', 'denim facts'],
#  [0.3, 'ohio facts', 'ocean facts'],
#  [0.19047619047619047, 'somalia national anthem', 'bolivia national anthem'],
#  [0.28, 'wind fact number ten card', 'cloud fact number six card'],
#  [0.2857142857142857, 'welcome facts', 'aquarium facts'],
#  [0.3076923076923077, 'sunrise facts', 'wondrous facts'],
#  [0.1,
#   'top paid ios apps - italy unofficial',
#   'top free ios apps- italy unofficial'],
#  [0.3076923076923077,
#   'austria fact number eight card',
#   'morocco fact number eighteen card'],
#  [0.3076923076923077,
#   'rainbow fact number ten card',
#   'austria fact number one card'],
#  [0.24324324324324326,
#   'winning numbers for ohio pick 3 evening',
#   'winning numbers for tennessee cash 3 evening'],
#  [0.29411764705882354, 'hot 93.1', 'rock 93-7'],
#  [0.1111111111111111,
#   'england fact number nine card',
#   'england fact number three card'],
#  [0.2894736842105263,
#   'winning numbers for arkansas cash 3 midday',
#   'winning numbers for illinois pick 4 midday'],
#  [0.3,
#   'banana fact number sixteen card',
#   'hurricane fact number thirteen card'],
#  [0.28, '104.9 the surf', '104.7 the cave'],
#  [0.2,
#   'denmark fact number nineteen card',
#   'banana fact number nineteen card'],
#  [0.25, 'calvary chapel anaheim', 'calvary chapel madison'],
#  [0.14814814814814814,
#   'snow report for copper mountain',
#   'snow report for hunter mountain'],
#  [0.24, 'mango fact number ten card', 'rainbow fact number nine card'],
#  [0.2857142857142857,
#   'mushroom fact number six card',
#   'star fact number sixteen card'],
#  [0.2, 'suits facts', 'goose facts'],
#  [0.3, 'body facts', 'bonner facts'],
#  [0.27586206896551724,
#   'austria fact number eighteen card',
#   'nuclear fact number fourteen card'],
#  [0.28, 'snow fact number twelve card', 'math fact number five card'],
#  [0.2727272727272727, 'virginia facts home card', 'illinois facts home card'],
#  [0.3, 'rhino facts', 'bike facts'],
#  [0.30434782608695654,
#   'kazakhstan national anthem',
#   'kiribati national anthem'],
#  [0.2631578947368421, 'cole community church', 'dewitt community church'],
#  [0.2222222222222222, 'smart egg', 'smart elf'],
#  [0.3, 'hippo facts', 'solo facts'],
#  [0.3076923076923077,
#   'snow report for mount seymour',
#   'snow report for bryce resort'],
#  [0.3, 'worthy facts', 'city facts'],
#  [0.25, 'mix 94.5', 'mix 95.9'],
#  [0.25, 'honey facts', 'hungary facts'],
#  [0.28, 'mango fact number nine card', 'thunder fact number one card'],
#  [0.2631578947368421, '94.1 the bear', '94.9 the breeze'],
#  [0.27586206896551724,
#   'argentina fact number nine card',
#   'new zealand fact number nine card'],
#  [0.2857142857142857, 'tiger facts home card', 'missouri facts home card'],
#  [0.2631578947368421, 'wicked local canton', 'wicked local orleans'],
#  [0.08, 'snow report for boyne mountain', 'snow report for loon mountain'],
#  [0, 'hola laughter', 'hola laughter'],
#  [0, 'unbearable news network', 'unbearable news network'],
#  [0.3, 'dance facts', 'geese facts'],
#  [0, 'recording library radio', 'recording library radio'],
#  [0, 'wicked local falmouth', 'wicked local falmouth'],
#  [0, 'capitals quiz', 'capitals quiz'],
#  [0, 'game of shares', 'game of shares'],
#  [0, 'malaysia fact number two card', 'malaysia fact number two card'],
#  [0, 'music info', 'music info'],
#  [0, 'st. augustine record', 'st. augustine record'],
#  [0.30434782608695654,
#   'turkey fact number two card',
#   'snow fact number five card'],
#  [0, 'dish tracker', 'dish tracker'],
#  [0, 'dice roller & coin flipper', 'dice roller & coin flipper'],
#  [0.25, 'amazing facts', 'gaming facts'],
#  [0.2, 'doc finder', 'drop finder'],
#  [0.2222222222222222,
#   'waterfall fact number ten card',
#   'pineapple fact number ten card'],
#  [0.3, 'daily laughter', 'daily counter'],
#  [0.19230769230769232,
#   'protein fact number nine card',
#   'star fact number nine card'],
#  [0.17647058823529413, 'family castle quiz', 'family castle news'],
#  [0.24, 'lightning fact number two card', 'malaysia fact number two card'],
#  [0.20689655172413793,
#   'nuclear fact number thirteen card',
#   'biology fact number thirteen card'],
#  [0.10344827586206896,
#   'venezuela fact number ten card',
#   'venezuela fact number eight card'],
#  [0.22727272727272727,
#   'sussex county fire scanner',
#   'morris county fire scanner'],
#  [0.3, 'llama facts', 'rock facts'],
#  [0.23809523809523808, 'koala facts home card', 'belgium facts home card'],
#  [0.15384615384615385, 'iowa city church', 'iowa city patch'],
#  [0.2777777777777778, 'wicked local bourne', 'wicked local waltham'],
#  [0.2, 'indian national anthem', 'sweden national anthem'],
#  [0.2413793103448276, 'remember when 1937', 'remember when 1986'],
#  [0, 'five sentences', 'five sentences'],
#  [0, 'rangers cup counter', 'rangers cup counter'],
#  [0, 'go army', 'go army'],
#  [0.2608695652173913,
#   'corn fact number two card',
#   'earth fact number ten card'],
#  [0.2727272727272727, 'guitar facts', 'year facts'],
#  [0.25, 'strange  facts', 'stress facts'],
#  [0.2222222222222222, 'remember when 1948', 'remember when 1939'],
#  [0.2962962962962963,
#   'carrot fact number thirteen card',
#   'mushroom fact number three card'],
#  [0.25,
#   'switzerland fact number seven card',
#   'england fact number seventeen card'],
#  [0.3076923076923077,
#   'tornado fact number two card',
#   'morocco fact number ten card'],
#  [0.2, 'wicked local brockton', 'wicked local burlington'],
#  [0.2, 'rain fact number thirteen card', 'rain fact number six card'],
#  [0.3, 'love facts', 'fuzzy facts'],
#  [0.29411764705882354, 'awesome poverty facts', 'awesome fruit facts'],
#  [0.3, 'mule facts', 'mims facts'],
#  [0.21739130434782608, '101.1 the wiz', '102.1 the wave'],
#  [0.3, 'art facts', 'corn facts'],
#  [0.2727272727272727, 'karin facts', 'cotton facts'],
#  [0.3076923076923077,
#   'corn fact number thirteen card',
#   'flood fact number seven card'],
#  [0.3, 'knight sounds', 'city sounds'],
#  [0.26666666666666666, 'llamas fun facts', 'awesome phone facts'],
#  [0.3076923076923077, 'italy facts', 'stan lee facts'],
#  [0.25, 'trendy facts', 'strained facts'],
#  [0.3076923076923077,
#   'belgium fact number four card',
#   'cloud fact number one card'],
#  [0.30434782608695654,
#   'jamaica facts home card',
#   'washington facts home card'],
#  [0.3076923076923077, 'animal trivia', 'indian trivia'],
#  [0.2916666666666667,
#   'spain fact number nine card',
#   'orange fact number eight card'],
#  [0.2222222222222222, 'remember when 1929', 'remember when 1933'],
#  [0.2727272727272727, 'hello facts', 'lovely facts'],
#  [0.21052631578947367, '94.9 the rock', '94.9 the wolf'],
#  [0.2962962962962963,
#   'coconut fact number five card',
#   'rainbow fact number nine card'],
#  [0.2916666666666667,
#   'earth fact number thirteen card',
#   'star fact number ten card'],
#  [0.2857142857142857, 'norway national anthem', 'finland national anthem'],
#  [0.1875,
#   'snow report for buffalo ski club',
#   'snow report for mansfield ski club'],
#  [0.3076923076923077,
#   'snow report for boston mills',
#   'snow report for hurricane ridge'],
#  [0.16666666666666666,
#   'snow report for lost valley',
#   'snow report for sun valley'],
#  [0.30434782608695654,
#   'snow report for mad river',
#   "snow report for sir sam's"],
#  [0.2222222222222222, 'remember when 1932', 'remember when 1999'],
#  [0.3076923076923077, 'spices trivia', 'texas trivia'],
#  [0, 'grayson burns', 'grayson burns'],
#  [0.3, 'emu facts', 'new facts'],
#  [0, 'deck of cards', 'deck of cards'],
#  [0, 'wilfred quotes', 'wilfred quotes'],
#  [0, 'radio mel blanc', 'radio mel blanc'],
#  [0, 'chuck norris facts (unofficial)', 'chuck norris facts (unofficial)'],
#  [0.3076923076923077,
#   'snow report for bogus basin',
#   'snow report for sugar mountain'],
#  [0.2777777777777778, 'unofficial docker news', 'unofficial india news'],
#  [0.24, 'turkey fact number eight card', 'belgium fact number eight card'],
#  [0.29411764705882354, 'mistry space facts', 'india space facts'],
#  [0.15789473684210525,
#   'top paid from apple books - canada unofficial',
#   'top paid from apple books - japan unofficial'],
#  [0.21428571428571427,
#   'tornado fact number eighteen card',
#   'waterfall fact number eighteen card'],
#  [0.2413793103448276, 'remember when 1978', 'remember when 1957'],
#  [0.28, 'fire fact number five card', 'rainbow fact number nine card'],
#  [0.2631578947368421, 'chad national anthem', 'yemen national anthem'],
#  [0.18518518518518517,
#   'corn fact number eleven card',
#   'corn fact number twelve card'],
#  [0.3, 'apple facts', 'coal facts'],
#  [0.2, 'q102', 'rock 102'],
#  [0.3, 'sock facts', 'coffee facts'],
#  [0, 'guess the month', 'guess the month'],
#  [0, 'boston guide', 'boston guide'],
#  [0, 'splat tim', 'splat tim'],
#  [0, 'keep it 100 girl podcast', 'keep it 100 girl podcast'],
#  [0, 'the oracle', 'the oracle'],
#  [0.25925925925925924, 'remember when 1926', 'remember when 1914'],
#  [0.2857142857142857, 'ireland national anthem', 'senegal national anthem'],
#  [0.3076923076923077, 'burger of the day', 'goal of the day'],
#  [0.3, 'swan facts', 'c++ facts'],
#  [0.2727272727272727, 'budget master', 'beat master'],
#  [0.2692307692307692,
#   'money fact number eighteen card',
#   'banana fact number nine card'],
#  [0, 'fast facts to save money', 'fast facts to save money'],
#  [0, 'revolution church', 'revolution church'],
#  [0.28, 'mango fact number one card', 'money fact number four card'],
#  [0, 'create', 'create'],
#  [0, '106.7 the river', '106.7 the river'],
#  [0.2962962962962963,
#   'lemon fact number seven card',
#   'hurricane fact number ten card'],
#  [0.2, '4 train trivia', '3 train trivia'],
#  [0.15384615384615385,
#   'cloud fact number seven card',
#   'cloud fact number five card'],
#  [0.15384615384615385, 'letter k facts', 'letter c facts'],
#  [0, 'depression facts', 'depression facts'],
#  [0, 'laughter bells', 'laughter bells'],
#  [0, 'ultimate history quiz', 'ultimate history quiz'],
#  [0.07317073170731707,
#   'hot tracks from apple music - japan unofficial',
#   'hot tracks from apple music - spain unofficial'],
#  [0.15384615384615385,
#   'orange fact number six card',
#   'orange fact number three card'],
#  [0, 'the newton kansan', 'the newton kansan'],
#  [0, 'flood fact number ten card', 'flood fact number ten card'],
#  [0.19230769230769232,
#   'math fact number eleven card',
#   'math fact number thirteen card'],
#  [0, 'crossroads church', 'crossroads church'],
#  [0, 'romantic robot', 'romantic robot'],
#  [0.2, 'cloud facts home card', 'illinois facts home card'],
#  [0.25, 'camels facts', 'color facts'],
#  [0.2222222222222222, 'iron facts', 'ai facts'],
#  [0.2916666666666667,
#   'snow report for bruce mound',
#   'snow report for greek peak'],
#  [0.15384615384615385,
#   'spain fact number seven card',
#   'money fact number seven card'],
#  [0.3, 'spur radio', 'sunny radio'],
#  [0.17857142857142858,
#   'orange fact number eleven card',
#   'cloud fact number eleven card'],
#  [0.2727272727272727, 'rising facts', 'surfing facts'],
#  [0.19047619047619047,
#   'sleep sounds: city sounds',
#   'sleep sounds: highway sounds'],
#  [0.3076923076923077, 'avocado facts', 'lavender facts'],
#  [0.2727272727272727, 'gaming facts', 'coding facts'],
#  [0.2857142857142857, 'tuvalu national anthem', 'uganda national anthem'],
#  [0.2727272727272727, 'let me choose!', 'help me choose'],
#  [0.16666666666666666,
#   'corn fact number ten card',
#   'flood fact number ten card'],
#  [0.25, 'corn fact number two card', 'cloud fact number five card'],
#  [0.3076923076923077, 'vertex sports', 'phoenix sports'],
#  [0,
#   'united states fact number seventeen card',
#   'united states fact number seventeen card'],
#  [0, 'bedtime', 'bedtime'],
#  [0.3, 'turkey facts', 'zika facts'],
#  [0, 'pick a name', 'pick a name'],
#  [0, 'sleep sounds: wind sounds', 'sleep sounds: wind sounds'],
#  [0.2413793103448276,
#   'nuclear fact number thirteen card',
#   'pineapple fact number thirteen card'],
#  [0.3, 'body facts', 'duh facts'],
#  [0.3, 'sun facts', 'fuzzy facts'],
#  [0.2857142857142857, 'thailand facts home card', 'kenya facts home card'],
#  [0.3, 'snake facts', 'sweet facts'],
#  [0.25, 'delaware facts home card', 'netherlands facts home card'],
#  [0.3, 'book facts', 'fact facts'],
#  [0.2727272727272727, 'cherry facts', 'corgi facts'],
#  [0.2857142857142857, 'dragon facts', 'orangutan facts'],
#  [0.20588235294117646,
#   'denmark fact number seventeen card',
#   'venezuela fact number seventeen card'],
#  [0.3076923076923077,
#   'ambient visuals: space shuttle',
#   'ambient visuals: snow globe'],
#  [0.27586206896551724,
#   'mushroom fact number fourteen card',
#   'nuclear fact number fifteen card'],
#  [0.3076923076923077,
#   'star fact number five card',
#   'flood fact number twelve card'],
#  [0.19230769230769232,
#   'fast fact president truman',
#   'fast fact president monroe'],
#  [0.23076923076923078, 'random anything', 'random something'],
#  [0.3, 'calm sounds', 'crowd sounds'],
#  [0.10344827586206896,
#   'recycling fact number eight card',
#   'recycling fact number nine card'],
#  [0.2608695652173913,
#   'math fact number two card',
#   'time fact number three card'],
#  [0.21052631578947367, 'giraffe facts home card', 'horse facts home card'],
#  [0.1111111111111111,
#   'snow fact number eleven card',
#   'money fact number eleven card'],
#  [0.2, 'nepali national anthem', 'italy national anthem'],
#  [0.28, 'fire fact number ten card', 'earth fact number eleven card'],
#  [0.25, 'hola diversion', 'hey diversion'],
#  [0.3, 'diet facts', 'autumn facts'],
#  [0.2777777777777778, 'sunrise compliments', "friends' compliments"],
#  [0.2631578947368421, 'egypt national anthem', 'czech national anthem'],
#  [0.2916666666666667, 'pulse 101.7', 'hot 107.7'],
#  [0.2857142857142857, 'rhyme game', 'rat game'],
#  [0.28, 'orange fact number two card', 'hurricane fact number eight card'],
#  [0.25,
#   'coconut fact number eight card',
#   'satellite fact number eighteen card'],
#  [0.26666666666666666, 'loan calculator', 'keto calculator'],
#  [0.3, 'diet facts', 'chuck facts'],
#  [0.12, 'morocco fact number eight card', 'morocco fact number three card'],
#  [0.3, 'snake facts', 'sci facts'],
#  [0.2727272727272727, 'piano facts', 'pony facts'],
#  [0.3076923076923077, 'office trivia', 'texas trivia'],
#  [0.2857142857142857,
#   'mango fact number fourteen card',
#   'wind fact number thirteen card'],
#  [0.2608695652173913, 'bangladesh facts home card', 'england facts home card'],
#  [0.14814814814814814,
#   'turkey fact number fourteen card',
#   'star fact number fourteen card'],
#  [0, 'spectacular facts', 'spectacular  facts'],
#  [0.15384615384615385,
#   'top paid mac apps - united kingdom unofficial',
#   'top paid mac apps - united states unofficial'],
#  [0.14285714285714285,
#   'tennessee facts part two',
#   'tennessee facts part five'],
#  [0.3, 'light facts', 'twice facts'],
#  [0.3, 'zika facts', 'mike facts'],
#  [0.2631578947368421, 'haiti national anthem', 'morocco national anthem'],
#  [0, 'natural way', 'natural way'],
#  [0.16666666666666666, 'leap assistant', 'eve assistant'],
#  [0.26666666666666666, 'whittier daily news', 'winona daily news'],
#  [0.25925925925925924,
#   'coconut fact number five card',
#   'satellite fact number four card'],
#  [0.3, 'foodie facts', 'false facts'],
#  [0.3, 'utah facts', 'yoyo facts'],
#  [0.3076923076923077,
#   'nuclear fact number five card',
#   'star fact number nine card'],
#  [0.2692307692307692,
#   'corn fact number ten card',
#   'orange fact number six card'],
#  [0.2857142857142857, 'b101.5', 'wave 101fm'],
#  [0.27586206896551724,
#   'spain fact number fourteen card',
#   'nuclear fact number fifteen card'],
#  [0.2727272727272727, 'bottle fact', 'cotton facts'],
#  [0.2962962962962963,
#   'satellite fact number five card',
#   'hurricane fact number four card'],
#  [0.25, 'prayer time', 'scare time'],
#  [0.3, 'yay facts', 'place facts'],
#  [0.3, 'cool 105.5', 'hot 1025'],
#  [0.08, 'wicked local east bridgewater', 'wicked local west bridgewater'],
#  [0.28, 'spain fact number four card', 'orange fact number one card'],
#  [0.2727272727272727, 'tennis facts', 'ferret facts'],
#  [0.2, 'ukraine national anthem', 'bhutan national anthem'],
#  [0.2, 'sun country', 'iron country'],
#  [0.2727272727272727, 'happy diwali', 'ask diwali'],
#  [0.3076923076923077,
#   'pumpkin fact number two card',
#   'hurricane fact number one card'],
#  [0.2222222222222222, 'palau national anthem', 'oman national anthem'],
#  [0.3023255813953488,
#   'top albums from apple music - canada unofficial',
#   'new releases from apple music - italy unofficial'],
#  [0.28, 'sunny 107.9', 'the fan 107.5'],
#  [0.21052631578947367, 'china facts home card', 'utah facts home card'],
#  [0.19230769230769232, 'remember when 1922', 'remember when 1984'],
#  [0.2916666666666667,
#   'corn fact number three card',
#   'turkey fact number two card'],
#  [0, 'word problems', 'word problems'],
#  [0, 'eagles fight song', 'eagles fight song'],
#  [0.23333333333333334,
#   'england fact number eleven card',
#   'morocco fact number eleven card'],
#  [0, 'palm bay guide', 'palm bay guide'],
#  [0.3, 'suriname national anthem', 'jordan national anthem'],
#  [0.2692307692307692,
#   'snow report for buena vista',
#   'snow report for shawnee mountain'],
#  [0.2222222222222222,
#   'banana fact number ten card',
#   'pineapple fact number nine card'],
#  [0.3, 'nepali national anthem', 'laos national anthem'],
#  [0.23076923076923078, 'cartoon trivia', 'darts trivia'],
#  [0.27586206896551724,
#   'lightning fact number fourteen card',
#   'hurricane fact number fifteen card'],
#  [0.19230769230769232,
#   'thunder fact number six card',
#   'morocco fact number six card'],
#  [0.23076923076923078, 'dog translator', 'mom translator'],
#  [0.20689655172413793,
#   'austria fact number twelve card',
#   'austria fact number fourteen card'],
#  [0.09090909090909091, 'kentucky facts part one', 'kentucky facts part nine'],
#  [0,
#   'seattle mortgage professor news brief',
#   'seattle mortgage professor news brief'],
#  [0, 'my braille cheat sheet', 'my braille cheat sheet'],
#  [0, 'video game history facts', 'video game history facts'],
#  [0, 'peak district weather', 'peak district weather'],
#  [0.2857142857142857, 'kentucky facts', 'monopoly facts'],
#  [0.2, 'wicked local rockport', 'wicked local westport'],
#  [0.3076923076923077, 'silicon facts', 'indian facts'],
#  [0.2727272727272727, 'decision time', 'decision coach'],
#  [0, 'three d. capital', 'three d. capital'],
#  [0, 'shovel facts', 'shovel facts'],
#  [0, 'alive or not', 'alive or not'],
#  [0, 'unofficial family matters facts', 'unofficial family matters facts'],
#  [0, 'tuner fish', 'tuner fish'],
#  [0.25, 'z facts', 'whoa facts'],
#  [0,
#   'trump wall statistics (unofficial)',
#   'trump wall statistics (unofficial)'],
#  [0, 'q107.3', 'q107.3'],
#  [0.2413793103448276,
#   'tornado fact number seven card',
#   'orange fact number eleven card'],
#  [0, 'daily check', 'daily check'],
#  [0.25, 'random fact', 'random workout'],
#  [0.21739130434782608,
#   'sleep sounds: snoring sounds',
#   'sleep sounds: harp sounds'],
#  [0.3076923076923077,
#   'banana fact number ten card',
#   'nuclear fact number one card'],
#  [0.3076923076923077,
#   'fire fact number eleven card',
#   'flood fact number nine card'],
#  [0.28, 'spain fact number five card', 'hurricane fact number two card'],
#  [0.2857142857142857, 'philemon trivia', 'button trivia'],
#  [0.3, 'heart facts', 'goat facts'],
#  [0.25925925925925924,
#   'big ten network maryland news',
#   'big ten network minnesota news'],
#  [0.23076923076923078,
#   'mushroom fact number nine card',
#   'turkey fact number nine card'],
#  [0.125, '106.3 the buzz', '106.5 the buzz'],
#  [0.23076923076923078,
#   'snow report for kelly canyon',
#   'snow report for wild mountain'],
#  [0.2727272727272727,
#   'winning numbers for oregon lucky lines',
#   'winning numbers for oregon megabucks'],
#  [0.3076923076923077, 'guess my number', 'find my number'],
#  [0.2413793103448276,
#   'mushroom fact number fourteen card',
#   'corn fact number fifteen card'],
#  [0.2727272727272727, 'llama facts', 'camel facts'],
#  [0, 'tennessee facts', 'tennessee facts'],
#  [0, '51% attack facts', '51% attack facts'],
#  [0, 'gummy bear wizard', 'gummy bear wizard'],
#  [0.18181818181818182, 'number flex', 'number dex'],
#  [0, 'wicked local quincy', 'wicked local quincy'],
#  [0.2608695652173913,
#   'snow report for pats peak',
#   'snow report for snow creek'],
#  [0.25, 'pot quiz', 'fit quiz'],
#  [0.3076923076923077,
#   'turkey fact number seven card',
#   'corn fact number six card'],
#  [0.2631578947368421, 'wicked local marlborough', 'wicked local maynard'],
#  [0.21212121212121213,
#   'venezuela fact number sixteen card',
#   'venezuela fact number twelve card'],
#  [0.25, 'mountain facts', 'austin facts'],
#  [0.26666666666666666, 'the views calendar', 'the mayan calendar'],
#  [0, 'yellowstone national park facts', 'yellowstone national park facts'],
#  [0.25, 'turkey fact number nine card', 'earth fact number three card'],
#  [0, 'snow report for eagle rock', 'snow report for eagle rock'],
#  [0.24, 'rain fact number seven card', 'money fact number one card'],
#  [0.2727272727272727,
#   'sleep sounds: clock sound',
#   'sleep sounds: india sounds'],
#  [0.2916666666666667,
#   'corn fact number nine card',
#   'flood fact number eight card'],
#  [0.21428571428571427, 'pro football news', 'mac football news'],
#  [0.25, 'my compliments', "anna's compliments"],
#  [0.23076923076923078, 'life motivation', 'dude motivation'],
#  [0.2962962962962963,
#   'denmark fact number ten card',
#   'thunder fact number one card'],
#  [0.14285714285714285, 'remember when 1978', 'remember when 1968'],
#  [0.2222222222222222, 'boat facts', 'night facts'],
#  [0.23076923076923078, 'shakespeare quotes', 'shakespeare facts'],
#  [0.3076923076923077,
#   'mushroom fact number ten card',
#   'morocco fact number five card'],
#  [0.25, 'snow report for beaver creek', 'snow report for pats peak'],
#  [0.28125,
#   'england fact number seventeen card',
#   'biology fact number sixteen card'],
#  [0.3, 'earth facts', 'burger facts'],
#  [0.3076923076923077, 'truth questions', 'tricky question'],
#  [0.2777777777777778, 'daily dose of space', 'daily dose of sunshine'],
#  [0.17857142857142858,
#   'snow report for castle mountain',
#   'snow report for holiday mountain'],
#  [0.25, 'philly transit', 'ac transit'],
#  [0.3, 'illinois facts part one', 'iowa facts part ten'],
#  [0.30434782608695654,
#   'snow report for red lodge',
#   'snow report for ski cooper'],
#  [0, 'the steel talk podcast', 'the steel talk podcast'],
#  [0, 'indian states and capitals', 'indian states and capitals'],
#  [0, 'scuba buddy', 'scuba buddy'],
#  [0, 'wishbone challenge', 'wishbone challenge'],
#  [0, 'oregon facts part three', 'oregon facts part three'],
#  [0, 'weekly fitness tips', 'weekly fitness tips'],
#  [0,
#   'ana connell - burbank ca real estate',
#   'ana connell - burbank ca real estate'],
#  [0.2727272727272727, 'opal facts', 'nepal facts'],
#  [0,
#   'journey community church, fairview park',
#   'journey community church, fairview park'],
#  [0, 'television facts', 'television facts'],
#  [0.25, '102.5 the game', '1025 kiss fm'],
#  [0.2727272727272727, 'honey facts', 'running facts'],
#  [0.3, 'poly count', 'daily counter'],
#  [0.2857142857142857,
#   'england fact number eight card',
#   'television fact number eight card'],
#  [0.2857142857142857, 'texas facts home card', 'jamaica facts home card'],
#  [0.3, 'state facts', 'place facts'],
#  [0.2222222222222222, 'remember when 1981', 'remember when 1953'],
#  [0.23529411764705882, 'wicked local weymouth', 'wicked local woburn'],
#  [0.25, 'carrot fact number fourteen card', 'lemon fact number thirteen card'],
#  [0.19230769230769232, 'remember when 1922', 'remember when 1985'],
#  [0.2, 'toad facts', 'tofu facts'],
#  [0,
#   'sleep w/ me | 18min guided sleep meditation',
#   'sleep w/ me | 18min guided sleep meditation'],
#  [0, 'last garage mystery', 'last garage mystery'],
#  [0, '92.9 the drive', '92.9 the drive'],
#  [0, "it's raining jokes!", "it's raining jokes!"],
#  [0.3, 'wine master', 'quote master'],
#  [0.2727272727272727, 'michigan facts home card', 'nevada facts home card'],
#  [0.21052631578947367, 'wicked local brighton', 'wicked local georgetown'],
#  [0.25925925925925924, '100.7 the zone', '106.7 the river'],
#  [0.18518518518518517,
#   'snow report for norway mountain',
#   'snow report for turner mountain'],
#  [0.26666666666666666,
#   'carrot fact number fourteen card',
#   'biology fact number fifteen card'],
#  [0.2, 'animal says', 'animal buzz'],
#  [0.2727272727272727, 'groovy facts', 'snoopy facts'],
#  [0.2916666666666667,
#   'snow report for snow summit',
#   'snow report for ski apache'],
#  [0.2857142857142857,
#   'astronaut fact number nine card',
#   'pineapple fact number nine card'],
#  [0.2727272727272727,
#   'snow fact number eight card',
#   'earth fact number ten card'],
#  [0.26666666666666666, 'the fish atlanta', 'the answer atlanta'],
#  [0.28, 'lemon fact number four card', 'corn fact number ten card'],
#  [0.28, 'money fact number eighteen card', 'lemon fact number five card'],
#  [0.3076923076923077,
#   'star fact number eighteen card',
#   'money fact number seven card'],
#  [0.2857142857142857, 'monstrous facts', 'mountain facts'],
#  [0.2962962962962963,
#   'snow report for mont gabriel',
#   'snow report for mount pleasant'],
#  [0.08695652173913043,
#   'math fact number five card',
#   'math fact number nine card'],
#  [0.23076923076923078, 'mouse facts new', 'macao facts new'],
#  [0.2962962962962963, '106.7 the fox', '1037 the buzz'],
#  [0.21052631578947367, 'fish facts home card', 'badger facts home card'],
#  [0.3, 'kelly facts', 'pony facts'],
#  [0.3, 'awesome facts', 'worm facts'],
#  [0.25, 'shark facts home card', 'kenya facts home card'],
#  [0.3, 'wine facts', 'wales facts'],
#  [0.25, 'sweden national anthem', 'tunisia national anthem'],
#  [0, 'task penguin', 'task penguin'],
#  [0.25, 'earth fact number five card', 'cloud fact number four card'],
#  [0.3, 'bio facts', "ben's facts"],
#  [0.2692307692307692,
#   'mushroom fact number nine card',
#   'corn fact number ten card'],
#  [0.2962962962962963,
#   'snow report for mont sutton',
#   'snow report for titus mountain'],
#  [0.125, 'dad jokes', 'dad joker'],
#  [0.14285714285714285, 'remember when 2018', 'remember when 2010'],
#  [0, 'whale facts home card', 'whale facts home card'],
#  [0, 'my cloud home', 'my cloud home'],
#  [0.25, 'hormone facts', 'corn facts'],
#  [0.2727272727272727, 'family health', 'family share'],
#  [0.26666666666666666,
#   'snow report for kimberley mountain',
#   'snow report for labrador mountain'],
#  [0.29411764705882354, 'fast fact missouri', 'fast fact saguaro'],
#  [0.3, 'hey radio', 'hippie radio'],
#  [0.3, 'wicked local bridgewater', 'wicked local brookline'],
#  [0.2222222222222222, 'mouse facts', 'dos facts'],
#  [0.26666666666666666, 'remember when 1976', 'remember when 1969'],
#  [0.2727272727272727, 'bassoon facts', 'butt facts'],
#  [0.3076923076923077,
#   'tornado fact number eight card',
#   'malaysia fact number two card'],
#  [0.25925925925925924,
#   'coconut fact number nine card',
#   'banana fact number one card'],
#  [0.3, 'daily facts', 'snail facts'],
#  [0.2631578947368421, 'syria national anthem', 'czech national anthem'],
#  [0.23809523809523808, 'iceland facts home card', 'china facts home card'],
#  [0.3, 'butt facts', 'state facts'],
#  [0.2727272727272727, 'game of words', 'game of phones'],
#  [0.2727272727272727, 'spatial sound', 'space sound'],
#  [0.13636363636363635, 'cat country 95.1', 'cat country 98.1'],
#  [0.3076923076923077,
#   'carrot fact number six card',
#   'orange fact number eight card'],
#  [0.17857142857142858,
#   'lemon fact number eleven card',
#   'money fact number seven card'],
#  [0.2, 'b102-9', 'b1027'],
#  [0.2727272727272727, 'magic 104.5', 'mix 104.3'],
#  [0.24, 'orange fact number ten card', 'money fact number five card'],
#  [0.15384615384615385,
#   'top free ios apps- united states unofficial',
#   'top free ios apps- united kingdom unofficial'],
#  [0.23333333333333334,
#   'lightning fact number eleven card',
#   'england fact number eleven card'],
#  [0.2692307692307692,
#   'giant panda facts home card',
#   'argentina facts home card'],
#  [0.2222222222222222, 'spain national anthem', 'china national anthem'],
#  [0.2222222222222222, 'it facts', 'boat facts'],
#  [0.25, 'earth facts', 'my facts'],
#  [0.2727272727272727, 'gosh facts', 'squash facts'],
#  [0.1111111111111111,
#   'relaxing sleep sounds: white noise',
#   'relaxing sleep sounds: blue noise'],
#  [0.23809523809523808,
#   'pine chapel baptist church',
#   'pine grove baptist church'],
#  [0.3, 'adam facts', 'dope facts'],
#  [0.3, 'announcements', 'appointments'],
#  [0.3, 'wales facts', 'wow facts'],
#  [0.08333333333333333,
#   'cloud fact number nine card',
#   'cloud fact number ten card'],
#  [0.2222222222222222, 'aha facts', 'hot facts'],
#  [0.3076923076923077,
#   'snow report for vail resort',
#   'snow report for villa olivia'],
#  [0.0625, 'celebrity gossips', 'celebrity gossip'],
#  [0.13793103448275862, 'remember when 1966', 'remember when 1964'],
#  [0.3, 'new zealand fact number one card', 'england fact number twenty card'],
#  [0, 'rio', 'rio'],
#  [0, 'kuala lumpur guide', 'kuala lumpur guide'],
#  [0.2222222222222222, 'iran national anthem', 'haiti national anthem'],
#  [0.3, 'dogs facts', 'hockey facts'],
#  [0.16, 'classic hits 93.7', 'classic hits 93.9'],
#  [0.25, 'best facts', 'chemist facts'],
#  [0.3, 'quake facts', 'will facts'],
#  [0.24, 'austria fact number eight card', 'belgium fact number eight card'],
#  [0.17857142857142858,
#   'snow report for copper mountain',
#   'snow report for schweitzer mountain'],
#  [0.3, 'beer advisor', 'food advisor'],
#  [0.25, 'koala facts home card', 'duck facts home card'],
#  [0.22727272727272727, 'hot 104.7', 'power 105.7'],
#  [0.1951219512195122,
#   'top albums from apple music - spain unofficial',
#   'hot tracks from apple music - spain unofficial'],
#  [0.08823529411764706,
#   'easy space definitions number two card',
#   'easy space definitions number one card'],
#  [0.3076923076923077, 'heartbeat sounds', 'upbeat sounds'],
#  [0.3076923076923077,
#   'money fact number thirteen card',
#   'morocco fact number one card'],
#  [0, 'overnight underground podcast', 'overnight underground podcast'],
#  [0.3, 'fox facts', 'shark facts'],
#  [0.30303030303030304,
#   'venezuela fact number seven card',
#   'switzerland fact number eleven card'],
#  [0, 'born ready', 'born ready'],
#  [0, 'story world', 'story world'],
#  [0.3, 'weed facts', 'peachy facts'],
#  [0.22727272727272727, 'magic 103.9', 'radio 103.9'],
#  [0.3076923076923077, 'my name picker', 'funny name picker'],
#  [0.26666666666666666,
#   'galaxy fact number fifteen card',
#   'malaysia fact number fourteen card'],
#  [0.08, 'lemon fact number four card', 'lemon fact number five card'],
#  [0.3076923076923077,
#   'banana fact number five card',
#   'protein fact number four card'],
# ...
#   'orange fact number five card'],
#  [0.3, 'league facts', 'yoga facts'],
#  [0.23809523809523808, 'hurricane facts home card', 'ireland facts home card'],
#  [0, 'letter n facts', 'letter n facts'],
#  [0.2222222222222222, 'iran national anthem', 'chad national anthem'],
#  [0.3, 'pig facts', 'paint facts'],
#  [0.2727272727272727, 'polish facts', 'place facts'],
#  [0.3, 'moon facts', 'lion facts'],
#  [0.2222222222222222, 'bee facts', 'bat facts'],
#  [0.13793103448275862, 'remember when 1926', 'remember when 1906'],
#  [0.2, 'rain fact number twelve card', 'rain fact number nine card'],
#  [0.3, 'snow facts', 'taco facts'],
#  [0.30434782608695654, 'mexico facts home card', 'portugal facts home card'],
#  [0.14814814814814814,
#   'morocco fact number twelve card',
#   'star fact number twelve card'],
#  [0.2962962962962963,
#   'money fact number thirteen card',
#   'morocco fact number seven card'],
#  [0.3076923076923077, 'capital finder', 'capital guesser'],
#  [0.3, 'two facts', 'train facts'],
#  [0.25, 'wind fact number three card', 'cloud fact number one card'],
#  [0, 'formula one facts', 'formula 1 facts'],
#  [0.25, 'lemon fact number fifteen card', 'corn fact number sixteen card'],
#  [0.3076923076923077,
#   'corn fact number five card',
#   'austria fact number one card'],
#  [0, 'flip a toast', 'flip a toast'],
#  [0, 'city builder', 'city builder'],
#  [0, 'cleveland heights patch', 'cleveland heights patch'],
#  [0, '96.7 the eagle', '96.7 the eagle'],
#  [0, 'unofficial honda accord facts', 'unofficial honda accord facts'],
#  [0.3, 'workout timer', 'workout tips'],
#  [0.2727272727272727, 'hidden facts', 'divine facts'],
#  [0.24, 'rain fact number four card', 'thunder fact number five card'],
#  [0, 'random laugh', 'random laugh'],
#  [0, 'studying relaxing music', 'studying relaxing music'],
#  [0, 'champagne cork pop', 'champagne cork pop'],
#  [0, 'friendly fun fact', 'friendly fun fact'],
#  [0, 'daily detroit', 'daily detroit'],
#  [0.2222222222222222, 'state quiz', 'steam quiz'],
#  [0.3076923076923077, 'shovel facts', 'trivial facts'],
#  [0.17391304347826086,
#   'math fact number one card',
#   'earth fact number ten card'],
#  [0.3076923076923077, 'camera control', 'vera control'],
#  [0.2962962962962963,
#   'time fact number seven card',
#   'turkey fact number fifteen card'],
#  [0.13636363636363635, 'iceland facts home card', 'england facts home card'],
#  [0.25, 'daily adventure', 'hola adventure'],
#  [0.14285714285714285,
#   'rainbow fact number fifteen card',
#   'morocco fact number fifteen card'],
#  [0.2727272727272727, 'slovenia national anthem', 'indonesia national anthem'],
#  [0, 'scientific seven minute workout', 'scientific seven minute workout'],
#  [0, 'ruckus unleashed', 'ruckus unleashed'],
#  [0, 'meta trivia', 'meta trivia'],
#  [0, 'donkey facts', 'donkey facts'],
#  [0, 'cmu bus schedule', 'cmu bus schedule'],
#  [0, 'snow report for bousquet ski area', 'snow report for bousquet ski area'],
#  [0.3076923076923077, 'quantum facts', 'carbon facts'],
#  [0.3076923076923077,
#   'denmark fact number eight card',
#   'star fact number three card'],
#  [0.3076923076923077,
#   'morocco fact number four card',
#   'malaysia fact number nine card'],
#  [0.2222222222222222, 'cow sounds', 'calm sounds'],
#  [0.25, 'music charts', 'music box'],
#  [0.3076923076923077,
#   'wind fact number ten card',
#   'biology fact number two card'],
#  [0.20833333333333334,
#   'cloud fact number five card',
#   'flood fact number three card'],
#  [0.25, 'spain fact number ten card', 'star fact number four card'],
#  [0.2222222222222222, 'cat facts', 'math facts'],
#  [0.27586206896551724, 'remember when 1909', 'remember when 1974'],
#  [0.3, 'fuzzy facts', 'butt facts'],
#  [0.3076923076923077, 'car doors sound', 'garage door sound'],
#  [0.23809523809523808, 'ultimate sports trivia', 'ultimate sports quiz'],
#  [0.3,
#   'switzerland fact number one card',
#   'new zealand fact number eight card'],
#  [0.3, 'chess facts', 'cheetah facts'],
#  [0.2, 'home connect dryer', 'home connect washer'],
#  [0.17857142857142858,
#   'protein fact number seven card',
#   'orange fact number seven card'],
#  [0.24, 'belgium fact number two card', 'morocco fact number two card'],
#  [0.2692307692307692, '103.9 the planet', '103.5 the champ'],
#  [0.2962962962962963,
#   'banana fact number ten card',
#   'coconut fact number three card'],
#  [0.21428571428571427,
#   'snow report for christie mountain',
#   'snow report for showdown mountain'],
#  [0.1875, 'running motivation', 'morning motivation'],
#  [0.2222222222222222,
#   'banana fact number nine card',
#   'denmark fact number nine card'],
#  [0.3, 'mark facts', 'mummy facts'],
#  [0.2, 'kohli facts', 'pony facts'],
#  [0.19230769230769232,
#   'coconut fact number eight card',
#   'orange fact number eight card'],
#  [0.19047619047619047,
#   'sleep sounds: womb sounds',
#   'sleep sounds: harp sounds'],
#  [0.14814814814814814, '100.7 the bay', '100.7 the point'],
#  [0.2631578947368421, 'laos national anthem', 'benin national anthem'],
#  [0.25, 'unknown facts', 'untold facts'],
#  [0.2413793103448276,
#   'banana fact number nineteen card',
#   'pineapple fact number thirteen card'],
#  [0.3076923076923077,
#   'money fact number six card',
#   'malaysia fact number one card'],
#  [0.21428571428571427,
#   'snow report for black mountain',
#   'snow report for mccauley mountain'],
#  [0.3, 'dubai facts', 'high facts'],
#  [0.2857142857142857, 'cricket facts', 'crocodile facts'],
#  [0, 'mock news', 'mock news'],
#  [0.28, 'rainbow fact number nine card', 'flood fact number ten card'],
#  [0, 'cruel work assistant', 'cruel work assistant'],
#  [0, 'pride history', 'pride history'],
#  [0.20689655172413793,
#   'tornado fact number seven card',
#   'protein fact number seven card'],
#  [0, 'connor birthday counter', 'connor birthday counter'],
#  [0.23076923076923078, 'business stories', 'disney stories'],
#  [0.25925925925925924,
#   'mushroom fact number eight card',
#   'austria fact number eighteen card'],
#  [0.2962962962962963,
#   'england fact number ten card',
#   'thunder fact number twelve card'],
#  [0.15384615384615385,
#   'snow fact number twelve card',
#   'flood fact number twelve card'],
#  [0.23076923076923078, 'remember when 1924', 'remember when 1998'],
#  [0.3, 'lion facts', 'adam facts'],
#  [0.2, 'fast fruit facts', 'fresh fruit facts'],
#  [0.1,
#   'denmark fact number nineteen card',
#   'denmark fact number fourteen card'],
#  [0.3, 'malawi national anthem', 'kuwait national anthem'],
#  [0.25, 'ace facts', 'all facts'],
#  [0.17857142857142858,
#   'snow report for nordic mountain',
#   'snow report for shawnee mountain'],
#  [0.2777777777777778, 'wicked local bourne', 'wicked local lincoln'],
#  [0.2727272727272727, 'hot 1017', 'hot 106.1'],
#  [0.1875, 'power 96.3', 'go 96.3'],
#  [0.3076923076923077,
#   'lemon fact number five card',
#   'hurricane fact number ten card'],
#  [0.2857142857142857, 'the lobster quiz', 'the first quiz'],
#  [0, 'abs workout | get a six pack', 'abs workout | get a six pack'],
#  [0,
#   'unofficial major league baseball update',
#   'unofficial major league baseball update'],
#  [0.3076923076923077, 'sound of birds', 'sound of the day'],
#  [0.14285714285714285, 'remember when 1936', 'remember when 1939'],
#  [0, 'ten pin bowling', 'ten pin bowling'],
#  [0.27586206896551724,
#   'recycling fact number four card',
#   'fast food fact number four card'],
#  [0, 'slogan machine', 'slogan machine'],
#  [0, 'everything about smart meters', 'everything about smart meters'],
#  [0.14814814814814814,
#   'snow report for turner mountain',
#   'snow report for willard mountain'],
#  [0.25, 'who goes first', 'who goes next'],
#  [0.30434782608695654,
#   'snow fact number four card',
#   'earth fact number six card'],
#  [0.20689655172413793,
#   'snow report for mammoth mountain',
#   'snow report for bristol mountain'],
#  [0.3, 'money facts', 'paint facts'],
#  [0.28, 'math fact number ten card', 'lemon fact number five card'],
#  [0.21739130434782608,
#   'time fact number five card',
#   'math fact number nine card'],
#  [0.2857142857142857, 'indian national anthem', 'bahamas national anthem'],
#  [0.2857142857142857, 'malaysia facts home card', 'wyoming facts home card'],
#  [0.27586206896551724,
#   'biology fact number thirteen card',
#   'galaxy fact number three card'],
#  [0.30434782608695654,
#   'kyrgyzstan national anthem',
#   'grenada national anthem'],
#  [0, 'usa facts', 'usa facts'],
#  [0, 'cricket fun facts', 'cricket fun facts'],
#  [0, "sam's pick 'em facts", "sam's pick 'em facts"],
#  [0.23076923076923078,
#   'austria fact number nine card',
#   'flood fact number nine card'],
#  [0, 'hemp oil extract', 'hemp oil extract'],
#  [0,
#   'breathtaking & mind-boggling facts',
#   'breathtaking & mind-boggling facts'],
#  [0.2777777777777778, 'southside baptist church', 'salem baptist church'],
#  [0, 'repeat after me', 'repeat after me'],
#  [0.3, 'key facts', 'fact facts'],
#  [0.2682926829268293,
#   'top albums from apple music - spain unofficial',
#   'top songs from apple music - canada unofficial'],
#  [0, 'denmark fact number seven card', 'denmark fact number seven card'],
#  [0.3076923076923077,
#   'mushroom fact number three card',
#   'thunder fact number four card'],
#  [0, 'gracie balance briefing', 'gracie balance briefing'],
#  [0.2727272727272727, 'q94', 'z94'],
#  [0.2222222222222222, 'book facts', 'wool facts'],
#  [0.2222222222222222, 'hot 101', 'rooster 101'],
#  [0, 'simple productivity tips', 'simple productivity tips'],
#  [0, 'nantucket inquirer & mirror', 'nantucket inquirer & mirror'],
#  [0.23809523809523808, 'brazil facts home card', 'crab facts home card'],
#  [0.2, 'awful  facts', 'abel facts'],
#  [0.2777777777777778, 'wicked local stoneham', 'wicked local truro'],
#  [0.2962962962962963,
#   'pumpkin fact number four card',
#   'protein fact number eight card'],
#  [0.2857142857142857, 'nutrition facts', 'abortion facts'],
#  [0.3, 'easter facts', 'aussie facts'],
#  [0.2727272727272727, 'summer facts', 'superb facts'],
#  [0.15384615384615385,
#   'snow report for copper mountain',
#   'snow report for elk mountain'],
#  [0.11538461538461539,
#   'austria fact number four card',
#   'austria fact number ten card'],
#  [0.2727272727272727, 'car facts', 'comic facts'],
#  [0.15384615384615385, 'galaxy facts', 'alex facts'],
#  [0.17857142857142858,
#   'coconut fact number six card',
#   'satellite fact number six card'],
#  [0, 'baby diary', 'baby diary'],
#  [0.2, 'georgia facts home card', 'shark facts home card'],
#  [0, 'fast slicer sound', 'fast slicer sound'],
#  [0.3, 'drug facts', 'adam facts'],
#  [0, 'radio health journal', 'radio health journal'],
#  [0, 'college basketball odds', 'college basketball odds'],
#  [0.3, 'bear facts', 'bryce facts'],
#  [0, 'table trick', 'table trick'],
#  [0, 'three beers inn', 'three beers inn'],
#  [0,
#   'thanksgiving appetizer recipe ideas',
#   'thanksgiving appetizer recipe ideas'],
#  [0, 'popular gaming streams', 'popular gaming streams'],
#  [0, 'spider man trivia', 'spider man trivia'],
#  [0, 'lightning fact number six card', 'lightning fact number six card'],
#  [0.26666666666666666,
#   'top free mac apps - spain unofficial',
#   'top paid mac apps - italy unofficial'],
#  [0.16, 'lemon fact number three card', 'orange fact number three card'],
#  [0.3076923076923077, 'worst dad jokes', 'nicks dad jokes'],
#  [0, 'guild news today', 'guild news today'],
#  [0.26666666666666666, 'cell phone facts', 'so-cal fun facts'],
#  [0.25, 'marvel facts', 'normal facts'],
#  [0.3076923076923077,
#   'lightning fact number nine card',
#   'flood fact number ten card'],
#  [0.30434782608695654,
#   'oklahoma facts home card',
#   'tennessee facts home card'],
#  [0.2727272727272727, 'mystic guru', 'mystic mirror'],
#  [0.2857142857142857, 'lebanon national anthem', 'cameroon national anthem'],
#  [0.21428571428571427, 'daily motivation', 'funny motivation'],
#  [0.2903225806451613,
#   'venezuela fact number twelve card',
#   'biology fact number twelve card'],
#  [0.21428571428571427,
#   'top songs from apple music - italy unofficial',
#   'new releases from apple music - italy unofficial'],
#  [0.2916666666666667,
#   'spain fact number one card',
#   'fire fact number four card'],
#  [0.3076923076923077, 'exciting  facts', 'striking facts'],
#  [0.22727272727272727, 'x107.1', 'hot 1079'],
#  [0.2631578947368421, 'wicked local chatham', 'wicked local kingston'],
#  [0.2857142857142857,
#   'astronaut fact number four card',
#   'pineapple fact number four card'],
#  [0.2, 'key facts', 'kohli facts'],
#  [0.28, 'snow fact number four card', 'thunder fact number one card'],
#  [0.2916666666666667,
#   'earth fact number four card',
#   'wind fact number three card'],
#  [0.3076923076923077,
#   'snow fact number eleven card',
#   'star fact number five card'],
#  [0, 'mount pleasant church of christ', 'mount pleasant church of christ'],
#  [0.3, 'watch facts', 'sweet facts'],
#  [0.30434782608695654,
#   'snow report for pine knob',
#   'snow report for wolf ridge'],
#  [0.2, 'baby facts', 'rainy facts'],
#  [0, '1440 keys', '1440 keys'],
#  [0, 'motivator4lit', 'motivator4lit'],
#  [0, 'loving forever', 'loving forever'],
#  [0.2727272727272727, 'scala facts', 'soccer facts!'],
#  [0.2727272727272727, 'slacker radio', 'spur radio'],
#  [0.2962962962962963,
#   'carrot fact number seven card',
#   'orange fact number five card'],
#  [0.3, 'star facts', 'snack facts'],
#  [0.28, 'mango fact number five card', 'wind fact number four card'],
#  [0.3076923076923077,
#   'protein fact number one card',
#   'cloud fact number ten card'],
#  [0.2727272727272727, 'rocket facts', 'osaka facts'],
#  [0.3, 'fun trivia', 'author trivia'],
#  [0.3, 'tricky quiz', 'cookie quiz'],
#  [0.3076923076923077,
#   'belgium fact number four card',
#   'carrot fact number ten card'],
#  [0.3076923076923077,
#   'snow report for granite gorge',
#   'snow report for willamette pass'],
#  [0.21052631578947367, 'wild country 99', 'big country 99'],
#  [0.29411764705882354, 'a moment of india', 'a moment of clocks'],
#  [0.30434782608695654,
#   'mississippi facts part four',
#   'montana facts part four'],
#  [0.2916666666666667, 'oregon facts part six', 'louisiana facts part six'],
#  [0.23076923076923078, 'hola auxiliary', 'hi auxiliary'],
#  [0.2857142857142857, 'ukraine facts home card', 'illinois facts home card'],
#  [0.21739130434782608,
#   'cancer horoscope of the day',
#   'taurus horoscope of the day'],
#  [0.20689655172413793,
#   'morocco fact number seven card',
#   'pumpkin fact number seven card'],
#  [0, 'cricket scorecard', 'cricket scorecard'],
#  [0.2916666666666667, '102.9 the buzz', '104.9 the wolf'],
#  [0.3076923076923077,
#   'spain fact number nine card',
#   'wind fact number seven card'],
#  [0.3, 'fun facts', 'acne facts'],
#  [0.18518518518518517,
#   'rainbow fact number six card',
#   'banana fact number six card'],
#  [0.2, 'brain facts', 'bruce facts'],
#  [0.2903225806451613,
#   'tornado fact number seven card',
#   'recycling fact number seven card'],
#  [0.3076923076923077, 'kentucky facts', 'currency facts'],
#  [0.11538461538461539,
#   'snow report for grouse mountain',
#   'snow report for crabbe mountain'],
#  [0.3, 'mars facts', "ben's facts"],
#  [0.3, 'cyprus national anthem', 'basque national anthem'],
#  [0.23076923076923078, 'abortion facts', 'boron facts'],
#  [0.19047619047619047, 'fun 104.3', 'mega 1043'],
#  [0.16, 'rain fact number four card', 'lemon fact number four card'],
#  [0.2564102564102564,
#   'top paid from apple books - france unofficial',
#   'top free from apple books - mexico unofficial'],
#  [0.2222222222222222, 'dead quotes', 'bad quotes'],
#  [0.28, 'banana fact number two card', 'orange fact number eight card'],
#  [0.25, 'cactus facts', 'candid facts'],
#  [0, 'pearson revel', 'pearson revel'],
#  [0, 'whiskey facts', 'whiskey facts'],
#  [0, '5000 points dice game', '5000 points dice game'],
#  [0, 'oh - io', 'oh - io'],
#  [0.23076923076923078,
#   'lightning fact number nine card',
#   'wind fact number ten card'],
#  [0, 'greenwich time', 'greenwich time'],
#  [0, 'camp high rocks', 'camp high rocks'],
#  [0, 'midtown houston patch', 'midtown houston patch'],
#  [0, 'oklahoma trends', 'oklahoma trends'],
#  [0.23809523809523808, 'myanmar national anthem', 'panama national anthem'],
#  [0.28, 'snow report for bear mountain', 'snow report for mont sutton'],
#  [0.3076923076923077,
#   'banana fact number ten card',
#   'nuclear fact number nine card'],
#  ...]

# %%
            
#    #first create a dictionary with all skillname to CMU tranlations to speed up the process
#skilltocmu = {}
#uniqueskillnames = {}
#for market in ['UK','US', 'CA', 'IN', 'AU']:
#    uniqsk = set([])
#    skills = data[market]
#    for skillid, skillobj in skills.items():
#        name1 = skillobj['name'].lower()
#        uniqsk.add(name1)
#        cmuname = getPhoneticTranslation(name1)
#        if '_' not in cmuname:
#            skilltocmu[name1] = cmuname
#        
#    uniqueskillnames[market] = uniqsk
#    print('finished translating skill names to cmu for market', market)    

#second find levehenstein distances between all uinque skill names of every market
#ldd = {}
for market in ['UK']:#,'US', 'CA', 'IN', 'AU']:
    alldistances = []
    print('Processing market ', market)
    uniqsk = list(uniqueskillnames[market])
    #ldp = {}
    for i in range(len(uniqsk)):
        name1 = uniqsk[i].lower()
        if(name1 not in skilltocmu):
            continue
        cmuname1 = skilltocmu[name1]
        for j in range(i, len(uniqsk)):
            name2 = uniqsk[j].lower()
            if(name2 not in skilltocmu):
                continue
            cmuname2 = skilltocmu[name2]
            d=  levdistance(cmuname1, cmuname2)
            #alldistances.append( (d, name1, name2) )
            alldistances.append( d )
            #ldp[name1+'_'+name2] = d 
        
        if(i%1000 == 0):
            print('\tDistances computed ', i)
            
        #comment this part    
        #if(i > 2000):
        #    ldd[market] = ldp
        #    break
    #ldd[market] = ldp
    min01 = [d for d in alldistances if d <= 0.1 and d!=0]
    min02 = [d for d in alldistances if d <= 0.2 and d!=0]
    #we should count how many times this skills appear in the market!
    print('There are ', len(min01), 'skills within a ld of 0.1')
    print('There are ', len(min02), 'skills within a ld of 0.2')
    print('Total unique skill names ', len(uniqsk))
    
    print('Finished estiamting skill names levehenstein distances for market', market)
# Out:
# finished translating skill names to cmu for market UK
# finished translating skill names to cmu for market US
# finished translating skill names to cmu for market CA
# finished translating skill names to cmu for market IN
# finished translating skill names to cmu for market AU
# Processing market  UK
# 	Distances computed  2000
# 	Distances computed  4000
# 	Distances computed  5000
# 	Distances computed  6000
# 	Distances computed  7000
# 	Distances computed  8000
# 	Distances computed  9000
# 	Distances computed  10000
# 	Distances computed  12000
# 	Distances computed  13000
# 	Distances computed  14000
# 	Distances computed  16000
# 	Distances computed  17000
# 	Distances computed  21000
# 	Distances computed  23000
# 	Distances computed  26000
# There are  765 skills within a ld of 0.1
# There are  6885 skills within a ld of 0.2
# Total unique skill names  27794
# Finished estiamting skill names levehenstein distances for market UK

# %%
start 00.19

# %% [raw]
# 23.44 : start UK
# 23.44 : 1k
# 23.45 : 2k
# 23.48 : 10k
# 23.57 : finihed

# %%
data = reloadData()
for market in ['UK']:#, 'AU', 'CA', 'IN', 'US']:
    print('Exploring market', market)
    sknames = list(uniqueskillnames[market])
    for i in range(len(sknames)):
        name1 = sknames[i].lower()
        for j in range(len(sknames)):
            name2 = sknames[j].lower()
            combo = name1+'_'+name2
            combo2 = name2+'_'+name1
            if(combo in ldd[market]):
                ld = ldd[market][combo]
                alldistances.append( (ld, name1, name2) ) 
            elif(combo2 in ldd[market]):
                ld = ldd[market][combo2]
                alldistances.append( (ld, name1, name2) ) 
                
        if(i%100 == 0):
            print('Analisys computed for ', i, 'skills')
        #print('explord skill', i)
        i+=1
        
    min01 = [(d,n1,n2) for (d,n1,n2) in alldistances if d <= 0.1 and d!=0]
    min02 = [(d,n1,n2) for (d,n1,n2) in alldistances if d <= 0.2 and d!=0]
    
    
    
    #skills = data[market]
    #alldistances = []
    #i = 0
    #for skillid, skillobj in skills.items():
    #    name1 = skillobj['name'].lower()
    #    #cmuname1 = skilltocmu[name1]
    #    for skillid2, skillobj2 in skills.items():
    #        name2 = skillobj2['name'].lower()
    #        #cmuname2 = skilltocmu[name2]
    #        combo = name1+'_'+name2
    #        combo2 = name2+'_'+name1
    #        if(combo in ldd[market]):
    #            ld = ldd[market][combo]
    #            alldistances.append( (ld, name1, name2) ) 
    #        elif(combo2 in ldd[market]):
    #            ld = ldd[market][combo2]
    #            alldistances.append( (ld, name1, name2) ) 
                
        
        
    #collected all releveant data for the market
    min01 = [(d,n1,n2) for (d,n1,n2) in alldistances if d <= 0.1 and d!=0]
    min02 = [(d,n1,n2) for (d,n1,n2) in alldistances if d <= 0.2 and d!=0]
    print( len(min01) )
    print( len(min02) )
# Out:
# ['../NewFullDataset/AU.json', '../NewFullDataset/CA.json', '../NewFullDataset/DE.json', '../NewFullDataset/ES.json', '../NewFullDataset/FR.json', '../NewFullDataset/IN.json', '../NewFullDataset/IT.json', '../NewFullDataset/JP.json', '../NewFullDataset/MX.json', '../NewFullDataset/UK.json', '../NewFullDataset/US.json']
#
# Total unique skills per market as per last week
# AU :  24062
# CA :  26009
# DE :  9082
# ES :  4756
# FR :  2282
# IN :  29249
# IT :  4202
# JP :  3519
# MX :  1972
# UK :  30975
# US :  60298
#
#
# Exploring market UK
# Analisys computed for  0 skills
# Analisys computed for  100 skills
# Analisys computed for  200 skills
# Analisys computed for  300 skills
# Analisys computed for  400 skills
# Analisys computed for  500 skills
# Analisys computed for  600 skills
# Analisys computed for  700 skills
# Analisys computed for  800 skills
# Analisys computed for  900 skills
# Analisys computed for  1000 skills
# Analisys computed for  1100 skills
# Analisys computed for  1200 skills
# Analisys computed for  1300 skills
# Analisys computed for  1400 skills
# Analisys computed for  1500 skills
# Analisys computed for  1600 skills
# Analisys computed for  1700 skills
# Analisys computed for  1800 skills
# Analisys computed for  1900 skills
# Analisys computed for  2000 skills
# Analisys computed for  2100 skills
# Analisys computed for  2200 skills
# Analisys computed for  2300 skills
# Analisys computed for  2400 skills
# Analisys computed for  2500 skills
# Analisys computed for  2600 skills
# Analisys computed for  2700 skills
# Analisys computed for  2800 skills
# Analisys computed for  2900 skills
# Analisys computed for  3000 skills
# Analisys computed for  3100 skills
# Analisys computed for  3200 skills
# Analisys computed for  3300 skills
# Analisys computed for  3400 skills
# Analisys computed for  3500 skills
# Analisys computed for  3600 skills
# Analisys computed for  3700 skills
# Analisys computed for  3800 skills
# Analisys computed for  3900 skills
# Analisys computed for  4000 skills
# Analisys computed for  4100 skills
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-03086e0a8c91> in <module>
#       9             combo = name1+'_'+name2
#      10             combo2 = name2+'_'+name1
# ---> 11             if(combo in ldd[market]):
#      12                 ld = ldd[market][combo]
#      13                 alldistances.append( (ld, name1, name2) )
#
# KeyboardInterrupt:

# %%
min01 = [(d,n1,n2) for (d,n1,n2) in alldistances if d <= 0.1 and d!=0]
min02 = [(d,n1,n2) for (d,n1,n2) in alldistances if d <= 0.2 and d!=0]
print( len(min01) )
print( len(min02) )
# Out:
# 232
# 540

# %% [raw]
# start 23.59
# 100   23.59
# 1200  12.04
# 1000k in 4' --> 160' for UK

# %%
min01
# Out:
# [(0.07692307692307693, 'Categories Game', 'Category Game'),
#  (0.1, 'Birthday Wisher', 'birthday wish'),
#  (0.07142857142857142, 'rock paper scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07692307692307693, 'Capitals Quiz', 'Capital Quiz'),
#  (0.07692307692307693, 'Capitals Quiz', 'Capital Quiz'),
#  (0.07692307692307693, 'Capitals Quiz', 'Capital Quiz'),
#  (0.08333333333333333, 'Forest sound', 'Forest Sounds'),
#  (0.08333333333333333, 'Voice of the Day', 'Verse of the Day'),
#  (0.0625, 'Random Cat Fact', 'Random Cat Facts'),
#  (0.0625, 'Random Cat Fact', 'Random Cat Facts'),
#  (0.0625, 'Random Cat Fact', 'Random Cat Facts'),
#  (0.06666666666666667, 'Stone Paper Scissor', 'Stone Paper Scissors'),
#  (0.07142857142857142, 'Heavy rain sound', 'Heavy Rain Sounds'),
#  (0.08333333333333333, 'Cicada sound', 'Cicada Sounds'),
#  (0.07142857142857142, 'rock paper scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock, Paper, Scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'Rock, Paper, Scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'Rock, Paper, Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock, Paper, Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock, Paper, Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock, Paper, Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock, Paper, Scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'Rock, Paper, Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock, Paper, Scissors', 'Rock Paper Scissor'),
#  (0.06666666666666667, 'stone paper scissor', 'Stone Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'rock paper scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy Facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy Facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy Facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy Facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy Facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy Facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy Facts'),
#  (0.09090909090909091, 'Crazy Fact', 'crazy facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy Facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy Facts'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy Facts!'),
#  (0.09090909090909091, 'Crazy Fact', 'Crazy Facts'),
#  (0.09090909090909091, 'Battle Tracks', 'Battle Traps'),
#  (0.1, 'Rudy Radio', 'Rowdy Radio'),
#  (0.1, 'Rudy Radio', 'Rood Radio'),
#  (0.1, 'Fun Facts', 'Funny Facts'),
#  (0.1, 'Fun Facts', 'Funny Facts'),
#  (0.1, 'Fun Facts', 'Funny Facts'),
#  (0.1, 'Fun Facts', 'Funny Facts'),
#  (0.1, 'Fun Facts', 'Funny Facts'),
#  (0.1, 'Fun Facts', 'Funny Facts'),
#  (0.1, 'Fun Facts', 'Funny Facts'),
#  (0.1, 'Fun Facts', 'funny facts'),
#  (0.1, 'Fun Facts', 'Funny facts'),
#  (0.1, 'Fun Facts', 'Funny facts'),
#  (0.1, 'Fun Facts', 'Funny facts'),
#  (0.1, 'Fun Facts', 'Funny facts'),
#  (0.1, 'Fun Facts', 'Funny facts'),
#  (0.1, 'Fun Facts', 'Funny facts'),
#  (0.1, 'Fun Facts', 'Funny Facts'),
#  (0.1, 'Fun Facts', 'Funny Facts'),
#  (0.1, 'Fun Facts', 'Funny facts'),
#  (0.1, 'Fun Facts', 'funny facts'),
#  (0.1, 'Fun Facts', 'Funny Facts'),
#  (0.07142857142857142, 'rock paper scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07692307692307693, 'Bedtime story', 'Bedtime Stories'),
#  (0.07692307692307693, 'Bedtime story', 'Bedtime stories'),
#  (0.07692307692307693, 'Bedtime story', 'Bedtime Stories'),
#  (0.07142857142857142, 'rock paper scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'rock paper scissors', 'Rock Paper Scissor'),
#  (0.1, 'Super Cards', 'Super Cars'),
#  (0.1, 'Super Cards', 'Super Cars'),
#  (0.1, 'Ocean sound', 'Ocean sounds'),
#  (0.1, 'Ocean sound', 'Ocean Sounds'),
#  (0.1, 'Train Sounds', 'Train sound'),
#  (0.1, 'Train Sounds', 'Rain Sounds'),
#  (0.1, 'Train Sounds', 'Rain sounds'),
#  (0.1, 'Train Sounds', 'Rain Sounds'),
#  (0.09090909090909091, 'Thunder sound', 'Thunder Sounds'),
#  (0.1, 'Train sound', 'Train Sounds'),
#  (0.1, 'Wind sound', 'Wind Sounds'),
#  (0.1, 'Nature sound', 'Nature Sounds'),
#  (0.1, 'Nature sound', 'Nature Sounds'),
#  (0.1, 'Nature sound', 'Nature Sounds'),
#  (0.06666666666666667, 'Water drop sound', 'Water Drop Sounds'),
#  (0.1, 'Nature Sounds', 'Nature sound'),
#  (0.1, 'Home Workout', 'Home Workouts'),
#  (0.06896551724137931,
#   'Relaxing Sleep Sounds: Fan Sounds',
#   'Relaxing Sleep Sounds: Rain Sounds'),
#  (0.1,
#   'Relaxing Sleep Sounds: Fan Sounds',
#   'Relaxing Sleep Sounds: Ocean Sounds'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'rock paper scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07142857142857142, 'Rock Paper Scissors', 'Rock Paper Scissor'),
#  (0.07407407407407407, 'Remember When 2019', 'Remember When 2015'),
#  (0.07407407407407407, 'Remember When 2019', 'Remember When 2011'),
#  (0.07142857142857142, 'Funny Cat Facts', 'Fun Cat Facts'),
#  (0.1, 'Nepali Date', 'Nepal Date'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'rock paper scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock, Paper, Scissors'),
#  (0.07142857142857142, 'Rock Paper Scissor', 'Rock Paper Scissors'),
#  (0.06666666666666667, 'stone paper scissor', 'Stone Paper Scissors')]
