# %%
import KfoldTest
import time

# %%
discardnoneSentences = False
maxrange = 10
if(discardnoneSentences is True):
    maxrange = 9 #ignore None label

#specify an index for every label so it does not change between executions
indextolabel = {0: 'Amazon Pay', 1: 'Device Address', 2: 'Device country and postal code', 
                3: 'Email Address', 4: 'Location Services', 5: 'Mobile Number', 6: 'Name', 
                7: 'Personal Information', 8: 'Skill Personisation', 9:'None'}

for label in range(1,2):

    configs = [
        #testing class proportion
        {'class_alexa_label_index': label, 'test_whole_dataset':False, 'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False, 'classproportion': 10, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False, 'classproportion': 3, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False, 'classproportion': 1, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False, 'classproportion': 2, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        #testing iterations
        {'class_alexa_label_index': label, 'test_whole_dataset':False, 'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':100  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False, 'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':10000  },
        #testing ksplits
        {'class_alexa_label_index': label, 'test_whole_dataset':False,'classproportion': 5, 'ksplits': 2, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False,'classproportion': 5, 'ksplits': 10, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        #testing ngrams
        {'class_alexa_label_index': label, 'test_whole_dataset':False,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':2, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False,'classproportion': 5, 'ksplits': 5, 'ngram_min':2, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        #testing use_tfidf, count binary, modified huber and alpha
        {'class_alexa_label_index': label, 'test_whole_dataset':False,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'modified_huber', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':False, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':False, 'count_binary':True, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':False, 'count_binary':True, 'svm_loss': 'modified_huber', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':False,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':False, 'count_binary':True, 'svm_loss': 'modified_huber', 'svm_alpha': 1e-3, 'svm_iter':1000  },
        #based on best results binary=true and tfidf false
        {"class_alexa_label_index": label, 'test_whole_dataset':False, "classproportion": 5, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False, "classproportion": 4, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False, "classproportion": 3, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False, "classproportion": 2, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False, "classproportion": 5, "ksplits": 3, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False, "classproportion": 5, "ksplits": 10, "ngram_min": 1, "ngram_max": 3, "use_tfidf":False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False, "classproportion": 5, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False, "classproportion": 5, "ksplits": 5, "ngram_min": 2, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False, "classproportion": 5, "ksplits": 5, "ngram_min": 1, "ngram_max": 2, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False, "classproportion": 5, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-04, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False, "classproportion": 5, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-03, "svm_iter": 1000},
        #based on other experiments, seems taht classproportion 2 works well for many clases
        {"class_alexa_label_index": label, 'test_whole_dataset':False,"classproportion": 2, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False,"classproportion": 2, "ksplits": 5, "ngram_min": 1, "ngram_max": 2, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False,"classproportion": 2, "ksplits": 5, "ngram_min": 2, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False,"classproportion": 2, "ksplits": 10, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False,"classproportion": 2, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False,"classproportion": 2, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False,"classproportion": 1, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False,"classproportion": 1, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False,"classproportion": 1, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-03, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':False,"classproportion": 1, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-03, "svm_iter": 1000},
        #
        {"class_alexa_label_index": label, 'test_whole_dataset':False,"classproportion": 1, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-03, "svm_iter": 1000},
        
        #
        # The same but testing on the whole dataset, meaning that kfold will be used to train combined with classproportion,
        # but the results will be tested on the rest of sentences before applying classproportion which discards some to balance the
        # datasets
        #
        #testing class proportion
        {'class_alexa_label_index': label, 'test_whole_dataset':True, 'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True, 'classproportion': 10, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True, 'classproportion': 3, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True, 'classproportion': 1, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True, 'classproportion': 2, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        #testing iterations
        {'class_alexa_label_index': label, 'test_whole_dataset':True, 'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':100  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True, 'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':10000  },
        #testing ksplits
        {'class_alexa_label_index': label, 'test_whole_dataset':True,'classproportion': 5, 'ksplits': 2, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True,'classproportion': 5, 'ksplits': 10, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        #testing ngrams
        {'class_alexa_label_index': label, 'test_whole_dataset':True,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':2, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True,'classproportion': 5, 'ksplits': 5, 'ngram_min':2, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        #testing use_tfidf, count binary, modified huber and alpha
        {'class_alexa_label_index': label, 'test_whole_dataset':True,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':True, 'count_binary':False, 'svm_loss': 'modified_huber', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':False, 'count_binary':False, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':False, 'count_binary':True, 'svm_loss': 'hinge', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':False, 'count_binary':True, 'svm_loss': 'modified_huber', 'svm_alpha': 1e-5, 'svm_iter':1000  },
        {'class_alexa_label_index': label, 'test_whole_dataset':True,'classproportion': 5, 'ksplits': 5, 'ngram_min':1, 'ngram_max':3, 'use_tfidf':False, 'count_binary':True, 'svm_loss': 'modified_huber', 'svm_alpha': 1e-3, 'svm_iter':1000  },
        #based on best results binary=true and tfidf false
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 5, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 4, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 3, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 2, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 5, "ksplits": 3, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 5, "ksplits": 10, "ngram_min": 1, "ngram_max": 3, "use_tfidf":False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 5, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 5, "ksplits": 5, "ngram_min": 2, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 5, "ksplits": 5, "ngram_min": 1, "ngram_max": 2, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 5, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-04, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 5, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-03, "svm_iter": 1000},
        #based on other experiments, seems taht classproportion 2 works well for many clases
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 2, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 2, "ksplits": 5, "ngram_min": 1, "ngram_max": 2, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 2, "ksplits": 5, "ngram_min": 2, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 2, "ksplits": 10, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "hinge", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 2, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 2, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 1, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 1, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-05, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 1, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-03, "svm_iter": 1000},
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 1, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-03, "svm_iter": 1000},
        #
        {"class_alexa_label_index": label, 'test_whole_dataset':True, "classproportion": 1, "ksplits": 5, "ngram_min": 1, "ngram_max": 3, "use_tfidf": False, "count_binary": True, "svm_loss": "modified_huber", "svm_alpha": 1e-03, "svm_iter": 1000},
    ]

        
    tic = time.perf_counter()
    KfoldTest.RunKFoldTest(configs, indexToLabel = indextolabel, discardNone=discardnoneSentences)
    toc = time.perf_counter()
    print('[TIMER] Label took {:0.4f} seconds'.format(toc-tic))
# Out:
# {0: 'Amazon Pay', 1: 'Device Address', 2: 'Device country and postal code', 3: 'Email Address', 4: 'Location Services', 5: 'Mobile Number', 6: 'Name', 7: 'Personal Information', 8: 'Skill Personisation', 9: 'None'}
# {'Amazon Pay': 0, 'Device Address': 1, 'Device country and postal code': 2, 'Email Address': 3, 'Location Services': 4, 'Mobile Number': 5, 'Name': 6, 'Personal Information': 7, 'Skill Personisation': 8, 'None': 9}
# ********************
#   PROCESSING CONFIG
# {'class_alexa_label_index': 1, 'test_whole_dataset': False, 'classproportion': 5, 'ksplits': 5, 'ngram_min': 1, 'ngram_max': 3, 'use_tfidf': True, 'count_binary': False, 'svm_loss': 'hinge', 'svm_alpha': 1e-05, 'svm_iter': 1000}
# ********************
# *Testing for  Label1
#
# Original length of all comments  10544
# Removed 34 repeated sentences from X1
# all data_balanced 1640
# data_balanced_class_0 279 data_balanced_class_1 1361
# 	>Train: 0=223, 1=1088, Test: 0=56, 1=273
# 	Total train+test 1640
# ...
